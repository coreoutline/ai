# %%
import pandas as pd

# %%
import re

# %%
import numpy as np

# %%
from huggingface_hub import login
from datasets import Dataset

# %%
urls = ["./data/conversations_1.csv","./data/conversations_2.csv","./data/conversations_3.csv","./data/conversations_4.csv"]

# %%
conversations = pd.concat([ pd.read_csv(url) for url in urls ])
# for url in urls:
#     print(url)
#     pd.read_csv(url)

# %%
conversations
# Out:
#                                     conversation_pairs
# 0                            \n\n    \n    \n</user>\n
# 1    \n    \n\n<prompt>What are some of the key ben...
# 2    \n\n    \n\n<prompt>What is Sinduja's area of ...
# 3    \n\n    Let's dive into some insights based on...
# 4    \n    \n\n<prompt>What was the initial approac...
# ..                                                 ...
# 985  \n\n<prompt>What is Buffer's mission?</prompt>...
# 986  \n    \n\n    <prompt>How can Baremetrics help...
# 987  \n    **Example:**\n\n    <prompt>What is the ...
# 988  </details>\n\n    <details>\n    <summary><b>P...
# 989  \n\n<prompt>What is the purpose of this code s...
#
# [2647 rows x 1 columns]

# %%
conversations_text = [ i for i in conversations['conversation_pairs'] ]

# %%
with open("./data/output.txt", "r", encoding="utf-8") as f:
    text = f.read()

# %%
text = text.replace("<prompt>", "\n <prompt>")
text = text.replace("<ans>", "\n <ans>")

# %%
lines  = text.split("\n")

# %%
prompts = []
answers = []

start = None
prompt = ""
answer = ""
current = "prompt"
for line in lines:
    if line.strip().startswith("<prompt>"):
        print("prompt: ", line)
        current = "prompt"
        
        if start == None:
            start = 0
            prompt = prompt + f" {line}"
        else:
            start +=1
            prompts.append(prompt)
            answers.append(answer)
            prompt = ""
            answer = ""
            prompt = prompt + f" {line}"
    if line.strip().startswith("<ans>"):
        print("answer: ", line)
        answer = answer + f" {line}"
        current = "answer"
# Out:
# prompt:   <prompt> Identify and describe the key factors that contribute to successful subscription growth strategies.
# answer:   <ans> Key factors that contribute to successful subscription growth strategies include understanding customer needs, providing valuable content, optimizing the checkout process, implementing AI-driven offers, and ensuring compliance with global business regulations.
# prompt:   <prompt> Explain the importance of a seamless checkout experience in subscription businesses.
# answer:   <ans> A seamless checkout experience is crucial in subscription businesses as it directly impacts customer retention and conversion rates. By minimizing friction and simplifying the payment process, businesses can increase customer satisfaction and encourage repeat subscriptions.
# prompt:   <prompt> Discuss the potential risks and challenges associated with homegrown billing systems.
# answer:   <ans> Homegrown billing systems may face challenges such as lack of scalability, increased risk of errors, and potential non-compliance with regulations. These systems may also be more difficult to maintain and update, leading to higher costs and decreased efficiency.
# prompt:   <prompt> Describe the benefits of using AI-driven offers to optimize customer retention in subscription businesses.
# answer:   <ans> AI-driven offers can help subscription businesses personalize their marketing efforts, identify and target high-value customers, and improve customer engagement. By leveraging data and predictive analytics, businesses can create more effective and targeted offers, ultimately increasing customer retention and revenue.
# prompt:   <prompt> Explain the role of eInvoicing in navigating global business expansion.
# answer:   <ans> EInvoicing plays a crucial role in navigating global business expansion by ensuring compliance with international regulations and simplifying the invoicing process. It enables businesses to efficiently manage invoices, reduce errors, and streamline communication with international customers.
# prompt:   <prompt> Discuss the impact of subscription growth on revenue growth at scale.
# answer:   <ans> Subscription growth can significantly impact revenue growth at scale by providing a predictable and recurring revenue stream. As more customers subscribe to a service, businesses can achieve economies of scale, reduce marketing costs, and increase overall profitability.
# prompt:   <prompt> Explain the concept of subscription ramps and their importance in multi-year deals.
# answer:   <ans> Subscription ramps refer to the strategic increase in the number of subscribers during the initial months of a subscription service. This approach is important in multi-year deals as it helps businesses achieve a higher customer acquisition cost (CAC) and ensures a steady growth trajectory.
# prompt:   <prompt> Discuss the best practices for a seamless billing system migration.
# answer:   <ans> Best practices for a seamless billing system migration include thorough planning, data validation, and testing, clear communication with customers, and ensuring compliance with regulations. It is also essential to have a well-defined migration strategy and to provide adequate training and support to employees.
# prompt:   <prompt> Explain the significance of the Gartner Magic Quadrant for Recurring Billing Applications in the subscription industry.
# answer:   <ans> The Gartner Magic Quadrant for Recurring Billing Applications is a highly regarded industry report that evaluates and ranks recurring billing applications based on their capabilities, market presence, and customer satisfaction. This report is significant in the subscription industry as it helps businesses identify and select the best billing solutions to support their subscription growth strategies.
# prompt:   <prompt> Discuss the potential growth opportunities for subscription businesses in the streaming industry.
# answer:   <ans> Potential growth opportunities for subscription businesses in the streaming industry include expanding into new markets, offering personalized content recommendations, implementing advanced analytics to improve customer retention, and leveraging partnerships with content creators and distributors.
# prompt:   <prompt> Explain the concept of subscription entitlement management and its importance in the billing process.
# answer:   <ans> Subscription entitlement management refers to the process of managing and tracking customer entitlements, such as discounts, loyalty points, and other benefits. It is crucial in the billing process as it ensures accurate billing, customer satisfaction, and compliance with contractual agreements. Effective entitlement management can also help businesses optimize their revenue and customer retention strategies.
# prompt:   <prompt> Explain the importance of subscriptions for revenue growth in D2C retailers.
# answer:   <ans> The importance of subscriptions for revenue growth in D2C retailers lies in their ability to foster customer loyalty, provide a steady revenue stream, and enable personalized experiences. Subscriptions offer a predictable and recurring revenue model, allowing retailers to plan and strategize their business more effectively. By offering personalized products and services, retailers can create a sense of exclusivity and value for their subscribers, leading to increased customer retention and lifetime value. Additionally, subscriptions provide valuable data insights that can be used to optimize the customer experience and tailor offerings to meet the evolving needs of the target audience.
# prompt:   <prompt> Discuss the role of personalization in subscription-based businesses.
# answer:   <ans> Personalization plays a crucial role in subscription-based businesses as it helps to create a unique and tailored experience for each subscriber. By leveraging data insights and customer preferences, businesses can curate personalized content, products, and services that align with the individual needs and interests of their subscribers. This level of personalization fosters a deeper connection between the business and its customers, leading to increased customer satisfaction, loyalty, and retention. Furthermore, personalization can drive higher engagement rates, encourage repeat purchases, and ultimately contribute to the growth and success of the subscription-based business.
# prompt:   <prompt> How can businesses leverage cancellation insights to improve their subscription model?
# answer:   <ans> Businesses can leverage cancellation insights to improve their subscription model by gaining a deeper understanding of customer behavior, preferences, and reasons for cancellation. By analyzing cancellation data, businesses can identify patterns and trends that may indicate areas for improvement in their subscription offerings, pricing, or communication strategies. This information can be used to refine the value proposition, enhance the customer experience, and address any pain points that may lead to cancellations. Additionally, cancellation insights can help businesses identify potential churn risks and proactively implement strategies to retain customers, such as targeted retention campaigns, personalized offers, and improved customer support.
# prompt:   <prompt> What strategies can be employed to retain subscribers in the face of increasing cancellations?
# answer:   <ans> To retain subscribers in the face of increasing cancellations, businesses can employ several strategies. Firstly, they can focus on improving the overall customer experience by providing
# prompt:   <prompt> Identify and describe the key factors that contribute to successful subscription growth strategies.
# answer:   <ans> Key factors that contribute to successful subscription growth strategies include understanding customer needs, providing valuable content, optimizing the checkout process, implementing AI-driven offers, and ensuring compliance with global business regulations.
# prompt:   <prompt> Explain the importance of a seamless checkout experience in subscription businesses.
# answer:   <ans> A seamless checkout experience is crucial in subscription businesses as it directly impacts customer retention and conversion rates. By minimizing friction and simplifying the payment process, businesses can increase customer satisfaction and encourage repeat subscriptions.
# prompt:   <prompt> Discuss the potential risks and challenges associated with homegrown billing systems.
# answer:   <ans> Homegrown billing systems may face challenges such as lack of scalability, increased risk of errors, and potential non-compliance with regulations. These systems may also be more difficult to maintain and update, leading to higher costs and decreased efficiency.
# prompt:   <prompt> Describe the benefits of using AI-driven offers to optimize customer retention in subscription businesses.
# answer:   <ans> AI-driven offers can help subscription businesses personalize their marketing efforts, identify and target high-value customers, and improve customer engagement. By leveraging data and predictive analytics, businesses can create more effective and targeted offers, ultimately increasing customer retention and revenue.
# prompt:   <prompt> Explain the role of eInvoicing in navigating global business expansion.
# answer:   <ans> EInvoicing plays a crucial role in navigating global business expansion by ensuring compliance with international regulations and simplifying the invoicing process. It enables businesses to efficiently manage invoices, reduce errors, and streamline communication with international customers.
# prompt:   <prompt> Discuss the impact of subscription growth on revenue growth at scale.
# answer:   <ans> Subscription growth can significantly impact revenue growth at scale by providing a predictable and recurring revenue stream. As more customers subscribe to a service, businesses can achieve economies of scale, reduce marketing costs, and increase overall profitability.
# prompt:   <prompt> Explain the concept of subscription ramps and their importance in multi-year deals.
# answer:   <ans> Subscription ramps refer to the strategic increase in the number of subscribers during the initial months of a subscription service. This approach is important in multi-year deals as it helps businesses achieve a higher customer acquisition cost (CAC) and ensures a steady growth trajectory.
# prompt:   <prompt> Discuss the best practices for a seamless billing system migration.
# answer:   <ans> Best practices for a seamless billing system migration include thorough planning, data validation, and testing, clear communication with customers, and ensuring compliance with regulations. It is also essential to have a well-defined migration strategy and to provide adequate training and support to employees.
# prompt:   <prompt> Explain the significance of the Gartner Magic Quadrant for Recurring Billing Applications in the subscription industry.
# answer:   <ans> The Gartner Magic Quadrant for Recurring Billing Applications is a highly regarded industry report that evaluates and ranks recurring billing applications based on their capabilities, market presence, and customer satisfaction. This report is significant in the subscription industry as it helps businesses identify and select the best billing solutions to support their subscription growth strategies.
# prompt:   <prompt> Discuss the potential growth opportunities for subscription businesses in the streaming industry.
# answer:   <ans> Potential growth opportunities for subscription businesses in the streaming industry include expanding into new markets, offering personalized content recommendations, implementing advanced analytics to improve customer retention, and leveraging partnerships with content creators and distributors.
# prompt:   <prompt> Explain the concept of subscription entitlement management and its importance in the billing process.
# answer:   <ans> Subscription entitlement management refers to the process of managing and tracking customer entitlements, such as discounts, loyalty points, and other benefits. It is crucial in the billing process as it ensures accurate billing, customer satisfaction, and compliance with contractual agreements. Effective entitlement management can also help businesses optimize their revenue and customer retention strategies.
# prompt:   <prompt> Explain the importance of subscriptions for revenue growth in D2C retailers.
# answer:   <ans> The importance of subscriptions for revenue growth in D2C retailers lies in their ability to foster customer loyalty, provide a steady revenue stream, and enable personalized experiences. Subscriptions offer a predictable and recurring revenue model, allowing retailers to plan and strategize their business more effectively. By offering personalized products and services, retailers can create a sense of exclusivity and value for their subscribers, leading to increased customer retention and lifetime value. Additionally, subscriptions provide valuable data insights that can be used to optimize the customer experience and tailor offerings to meet the evolving needs of the target audience.
# prompt:   <prompt> Discuss the role of personalization in subscription-based businesses.
# answer:   <ans> Personalization plays a crucial role in subscription-based businesses as it helps to create a unique and tailored experience for each subscriber. By leveraging data insights and customer preferences, businesses can curate personalized content, products, and services that align with the individual needs and interests of their subscribers. This level of personalization fosters a deeper connection between the business and its customers, leading to increased customer satisfaction, loyalty, and retention. Furthermore, personalization can drive higher engagement rates, encourage repeat purchases, and ultimately contribute to the growth and success of the subscription-based business.
# prompt:   <prompt> How can businesses leverage cancellation insights to improve their subscription model?
# answer:   <ans> Businesses can leverage cancellation insights to improve their subscription model by gaining a deeper understanding of customer behavior, preferences, and reasons for cancellation. By analyzing cancellation data, businesses can identify patterns and trends that may indicate areas for improvement in their subscription offerings, pricing, or communication strategies. This information can be used to refine the value proposition, enhance the customer experience, and address any pain points that may lead to cancellations. Additionally, cancellation insights can help businesses identify potential churn risks and proactively implement strategies to retain customers, such as targeted retention campaigns, personalized offers, and improved customer support.
# prompt:   <prompt> What strategies can be employed to retain subscribers in the face of increasing cancellations?
# answer:   <ans> To retain subscribers in the face of increasing cancellations, businesses can employ several strategies. Firstly, they can focus on improving the overall customer experience by providing high-quality products or services, personalized content, and excellent customer support. Secondly, businesses can implement targeted retention campaigns, such as offering exclusive discounts, rewards, or early access to new products or services, to incentivize subscribers to stay. Thirdly, businesses can leverage data insights to understand the reasons behind cancellations and address those pain points directly. This may involve refining the subscription model, adjusting pricing, or enhancing communication channels. Lastly, businesses can foster a sense of community and engagement among subscribers through social media, forums, or events, creating a stronger connection and sense of belonging that encourages loyalty and retention.
# prompt:   <prompt> How can businesses effectively communicate with their subscribers to minimize cancellations?
# answer:   <ans> Businesses can effectively communicate with their subscribers to minimize cancellations by implementing a proactive and transparent communication strategy. This includes providing clear and concise information about the subscription terms, benefits, and any changes to the service. Regular updates and reminders about upcoming renewals or new features can also help keep subscribers engaged and informed. Additionally, businesses can leverage personalized communication channels, such as email newsletters, social media, or mobile apps, to deliver tailored content and offers that resonate with subscribers' interests and preferences. By fostering open and ongoing dialogue, businesses can build trust, address concerns, and strengthen the relationship with their subscribers, ultimately reducing the likelihood of cancellations.
# prompt:   <prompt> What are some best practices for businesses to comply with the FTC's Click-to-Cancel Rule while retaining subscribers?
# answer:   <ans> To comply with the FTC's Click-to-Cancel Rule while retaining subscribers, businesses can adopt several best practices. Firstly, they should ensure that the cancellation process is easily accessible and clearly communicated to subscribers, with a prominent link or button that allows them to opt-out of receiving further communications. Secondly, businesses should provide a clear and concise explanation of the consequences of cancellation, such as the loss of access to certain features or benefits. Thirdly, businesses can offer incentives or benefits for subscribers who choose to stay, such as exclusive discounts, early access to new products, or personalized recommendations. Additionally, businesses should regularly review and update their cancellation policies and procedures to ensure compliance with the FTC's guidelines and maintain transparency with their subscribers.
# prompt:   <prompt> How can businesses use AI to leverage cancellation insights and improve their subscription model?
# answer:   <ans> Businesses can use AI to leverage cancellation insights and improve their subscription model by harnessing the power of data analytics and machine learning algorithms. AI can help businesses analyze large volumes of cancellation data to identify patterns, trends, and correlations that may indicate the underlying reasons for cancellations. By understanding these insights, businesses can make data-driven decisions to optimize their subscription offerings, pricing, and communication strategies. AI can also be used to develop predictive models that forecast potential churn risks, allowing businesses to proactively implement retention strategies and personalized offers. Furthermore, AI-powered chatbots or virtual assistants can provide real-time support and assistance to subscribers, addressing their concerns and queries promptly, thereby enhancing the overall customer experience and reducing the likelihood of cancellations.
# prompt:   <prompt> What are some effective strategies for businesses to foster customer loyalty and retention in their subscription-based businesses?
# answer:   <ans> To foster customer loyalty and retention in their subscription-based businesses, businesses can implement several effective strategies. Firstly, they can focus on delivering exceptional customer experiences by consistently providing high-quality products or services, personalized content, and excellent customer support. Secondly, businesses can implement loyalty programs or
# prompt:   <prompt>Identify and list the key financial metrics mentioned in the text, providing a brief explanation for each metric's significance in financial analysis.</ans>
# prompt:   <prompt>Extract and summarize the main process described in the text, focusing on its purpose and the steps involved.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be applied, detailing the potential outcomes and implications.</ans>
# prompt:   <prompt>Outline the potential risks and challenges that could be associated with the data or process described in the text.</ans>
# prompt:   <prompt>Generate a list of possible industry applications for the described data, explaining how it could be utilized in each industry.</ans>
# prompt:   <prompt>Propose a research question that could be explored further based on the information provided in the text.</ans>
# prompt:   <prompt>Describe a potential trend or pattern that could be inferred from the data mentioned in the text, including its possible causes and effects.</ans>
# prompt:   <prompt>Suggest a method for visualizing the data described in the text, explaining how it could enhance understanding and decision-making.</ans>
# prompt:   <prompt>Develop a set of criteria for evaluating the effectiveness of the process or metric described in the text.</ans>
# prompt:   <prompt>Imagine a competitive analysis based on the data provided; identify key competitors and how they might be performing relative to the described data.</ans>
# prompt:   <prompt>Propose a strategic initiative that could be developed using the data or process described in the text, detailing the expected benefits and challenges.</ans>
# prompt:   <prompt>Outline the potential impact of the described data on stakeholders, including customers, investors, and employees.</ans>
# prompt:   <prompt>Design a survey or questionnaire that could be used to gather additional data related to the topic discussed in the text.</ans>
# prompt:   <prompt>Create a hypothetical case study that applies the described data or process, illustrating its practical use and potential benefits.</ans>
# prompt:   <prompt>Suggest a method for collecting additional data that could complement the information provided in the text, enhancing its value for analysis.</ans>
# prompt:   <prompt>Propose a training or educational program that could be developed to help others understand and apply the described data or process effectively.</ans>
# prompt:   <prompt>Identify potential future developments or advancements that could be made in the area described by the text, considering current trends and technologies.</ans>
# prompt:   <prompt>Develop a risk management plan that addresses the potential risks associated with the data or process described in the text.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be used to inform policy decisions, detailing the decision-making process and expected outcomes.</ans>
# prompt:   <prompt>Propose a new product or service idea that could be developed using the data or process described in the text, including market analysis and target customer profile.</ans>
# prompt:   <prompt>Outline a potential partnership or collaboration opportunity that could be explored based on the data or process described in the text.</ans>
# prompt:   <prompt>Develop a set of best practices for implementing the described data or process effectively within an organization.</ans>
# prompt:   <prompt>Suggest a method for benchmarking the performance of the described data or process against industry standards or competitors.</ans>
# prompt:   <prompt>Create a hypothetical case study that demonstrates the potential impact of the described data or process on a specific business or industry.</ans>
# prompt:   <prompt>Propose a research methodology for conducting a comprehensive analysis of the data or process described in the text, including data collection, analysis, and interpretation.</ans>
# prompt:   <prompt>Develop a strategic plan for leveraging the described data or process to achieve specific business objectives or goals.</ans>
# prompt:   <prompt>Outline the potential ethical considerations or implications associated with the data or process described in the text.</ans>
# prompt:   <prompt>Suggest a method for integrating the described data or process into an existing business model or operational framework.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be used to inform investment decisions, detailing the decision-making process and expected outcomes.</ans>
# prompt:   <prompt>Propose a method for measuring the success or effectiveness of the described data or process, including key performance indicators (KPIs) and metrics.</ans>
# prompt:   <prompt>Develop a set of recommendations for improving the efficiency or effectiveness of the described data or process, based on best practices and industry standards.</ans>
# prompt:   <prompt>Outline a potential research study that could be conducted to further explore the implications of the data or process described in the text.</ans>
# prompt:   <prompt>Suggest a method for communicating the findings or insights derived from the described data or process to stakeholders, including non-technical audiences.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be used to inform public policy or regulatory decisions, detailing the decision-making process and expected outcomes.</ans>
# prompt:   <prompt>Propose a method for conducting a comparative analysis of the described data or process against alternative approaches or solutions.</ans>
# prompt:   <prompt>Develop a set of criteria for evaluating the accuracy and reliability of the data or process described in the text.</ans>
# prompt:   <prompt>Outline a potential research collaboration or partnership opportunity that could be explored based on the data or process described in the text.</ans>
# prompt:   <prompt>Suggest a method for incorporating the described data or process into a broader strategic framework or business plan.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be used to inform product development or innovation, detailing the decision-making process and expected outcomes.</ans>
# prompt:   <prompt>Propose a method for conducting a longitudinal study to track the long-term impact of the described data or process on an organization or industry.</ans>
# prompt:   <prompt>Develop a set of recommendations for addressing potential biases or limitations associated with the data or process described in the text.</ans>
# prompt:   <prompt>Outline a potential research project that could be conducted to explore the implications of the described data or process on a specific market or industry.</ans>
# prompt:   <prompt>Suggest a method for incorporating the described data or process into a risk management framework or strategy.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be used to inform corporate social responsibility (CSR) initiatives, detailing the decision-making process and expected outcomes.</ans>
# prompt:   <prompt>Propose a method for conducting a comparative analysis of the described data or process across different geographic regions or markets.</ans>
# prompt:   <prompt>Develop a set of criteria for evaluating the scalability and adaptability of the described data or process for different organizational contexts.</ans>
# prompt:   <prompt>Outline a potential research collaboration or partnership opportunity that could be explored based on the data or process described in the text, considering the potential benefits and challenges.</ans>
# prompt:   <prompt>Suggest a method for incorporating the described data or process into a broader organizational culture or change management initiative.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be used to inform talent acquisition or development strategies, detailing the decision-making process and expected outcomes.</ans>
# prompt:   <prompt>Propose a method for conducting a comparative analysis of the described data or process across different organizational structures or hierarchies
# prompt:   <prompt>Identify the key financial benefits mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The key financial benefits mentioned in the text include potential annual savings of around 1.2 million by reducing vendor count, increased customer retention, and exponential growth in retained revenue. Additionally, Chargebee's flexibility and ease of integration with other systems are highlighted as contributing factors to improved financial management and growth.</ans>
# prompt:   <prompt>Extract the various roles and titles of individuals mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The various roles and titles mentioned in the text include CEO, Global Head of Subscriptions, Senior Director of Product, Chief Product & Technology Officer, and members of the Chargebee community.</ans>
# prompt:   <prompt>Identify the different types of integrations and partnerships mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The text mentions integrated payment gateways, App Marketplace integrations, and support for multiple currencies as examples of the different types of integrations and partnerships mentioned.</ans>
# prompt:   <prompt>Extract the geographical scope of Chargebee's service, excluding direct references to the text.</prompt>
# answer:   <ans>Chargebee serves customers in 6,500 merchants across 227 countries and territories.</ans>
# prompt:   <prompt>Identify the specific features and capabilities of Chargebee's platform, excluding direct references to the text.</prompt>
# answer:   <ans>The text highlights features and capabilities such as usage-based pricing, predictability, billing rev/rec/receivables/retention analytics, strategy, industry, region, role, and retention as part of Chargebee's platform.</ans>
# prompt:   <prompt>Extract the various benefits and outcomes achieved by companies using Chargebee, excluding direct references to the text.</prompt>
# answer:   <ans>Companies using Chargebee have experienced benefits such as a 20% revenue growth, improved customer retention, and exponential growth in retained revenue. Additionally, Chargebee's flexibility and ease of integration have contributed to improved financial management and growth.</ans>
# prompt:   <prompt>Identify the different types of events and resources mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The text mentions events and resources such as conferences, events, the Subscription Academy, and the State of the Industry report as examples of the different types of events and resources mentioned.</ans>
# prompt:   <prompt>Extract the various aspects of Chargebee's product offerings, excluding direct references to the text.</prompt>
# answer:   <ans>Chargebee's product offerings include a billing platform, a subscription platform, and a product management platform, as well as a community of users and a subscription retention platform.</ans>
# prompt:   <prompt>Identify the different types of customer support and resources mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The text mentions resources such as the Subscription Academy, the State of the Industry report, and a community of users as examples of the different types of customer support and resources mentioned.</ans>
# prompt:   <prompt>Extract the various types of integrations and partnerships mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The text mentions integrated payment gateways, App Marketplace integrations, and support for multiple currencies as examples of the various types of integrations and partnerships mentioned.</ans>
# prompt:   <prompt>Identify the different types of financial metrics and data mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The text mentions financial metrics and data such as growth rates, revenue growth, customer retention, and retained revenue as examples of the different types of financial metrics and data mentioned.</ans>
# prompt:   <prompt>Extract the various types of customer-facing features and capabilities mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The text mentions features and capabilities such as usage-based pricing, predictability, billing rev/rec/receivables/retention analytics, strategy, industry, region, role, and retention as examples of the various types of customer-facing features and capabilities mentioned.</ans>
# prompt:   <prompt>Identify the different types of events and resources mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The text mentions events and resources such as conferences, events, the Subscription Academy, and the State of the Industry report as examples of the different types of events and resources mentioned.</ans>
# prompt:   <prompt>Extract the various types of financial benefits and outcomes mentioned in the text, excluding direct references to the text.</prompt>
# answer:   <ans>The text mentions financial benefits and outcomes such as potential annual savings, increased customer retention, and exponential growth in retained
# prompt:   <prompt> Identify and describe the key factors that contribute to successful subscription growth strategies.
# answer:   <ans> Key factors that contribute to successful subscription growth strategies include understanding customer needs, providing valuable content, optimizing the checkout process, implementing AI-driven offers, and ensuring compliance with global business regulations.
# prompt:   <prompt> Explain the importance of a seamless checkout experience in subscription businesses.
# answer:   <ans> A seamless checkout experience is crucial in subscription businesses as it directly impacts customer retention and conversion rates. By minimizing friction and simplifying the payment process, businesses can increase customer satisfaction and encourage repeat subscriptions.
# prompt:   <prompt> Discuss the potential risks and challenges associated with homegrown billing systems.
# answer:   <ans> Homegrown billing systems may face challenges such as lack of scalability, increased risk of errors, and potential non-compliance with regulations. These systems may also be more difficult to maintain and update, leading to higher costs and decreased efficiency.
# prompt:   <prompt> Describe the benefits of using AI-driven offers to optimize customer retention in subscription businesses.
# answer:   <ans> AI-driven offers can help subscription businesses personalize their marketing efforts, identify and target high-value customers, and improve customer engagement. By leveraging data and predictive analytics, businesses can create more effective and targeted offers, ultimately increasing customer retention and revenue.
# prompt:   <prompt> Explain the role of eInvoicing in navigating global business expansion.
# answer:   <ans> EInvoicing plays a crucial role in navigating global business expansion by ensuring compliance with international regulations and simplifying the invoicing process. It enables businesses to efficiently manage invoices, reduce errors, and streamline communication with international customers.
# prompt:   <prompt> Discuss the impact of subscription growth on revenue growth at scale.
# answer:   <ans> Subscription growth can significantly impact revenue growth at scale by providing a predictable and recurring revenue stream. As more customers subscribe to a service, businesses can achieve economies of scale, reduce marketing costs, and increase overall profitability.
# prompt:   <prompt> Explain the concept of subscription ramps and their importance in multi-year deals.
# answer:   <ans> Subscription ramps refer to the strategic increase in the number of subscribers during the initial months of a subscription service. This approach is important in multi-year deals as it helps businesses achieve a higher customer acquisition cost (CAC) and ensures a steady growth trajectory.
# prompt:   <prompt> Discuss the best practices for a seamless billing system migration.
# answer:   <ans> Best practices for a seamless billing system migration include thorough planning, data validation, and testing, clear communication with customers, and ensuring compliance with regulations. It is also essential to have a well-defined migration strategy and to provide adequate training and support to employees.
# prompt:   <prompt> Explain the significance of the Gartner Magic Quadrant for Recurring Billing Applications in the subscription industry.
# answer:   <ans> The Gartner Magic Quadrant for Recurring Billing Applications is a highly regarded industry report that evaluates and ranks recurring billing applications based on their capabilities, market presence, and customer satisfaction. This report is significant in the subscription industry as it helps businesses identify and select the best billing solutions to support their subscription growth strategies.
# prompt:   <prompt> Discuss the potential growth opportunities for subscription businesses in the streaming industry.
# answer:   <ans> Potential growth opportunities for subscription businesses in the streaming industry include expanding into new markets, offering personalized content recommendations, implementing advanced analytics to improve customer retention, and leveraging partnerships with content creators and distributors.
# prompt:   <prompt> Explain the concept of subscription entitlement management and its importance in the billing process.
# answer:   <ans> Subscription entitlement management refers to the process of managing and tracking customer entitlements, such as discounts, loyalty points, and other benefits. It is crucial in the billing process as it ensures accurate billing, customer satisfaction, and compliance with contractual agreements. Effective entitlement management can also help businesses optimize their revenue and customer retention strategies.
# prompt:   <prompt> Explain the importance of subscriptions for revenue growth in D2C retailers.
# answer:   <ans> The importance of subscriptions for revenue growth in D2C retailers lies in their ability to foster customer loyalty, provide a steady revenue stream, and enable personalized experiences. Subscriptions offer a predictable and recurring revenue model, allowing retailers to plan and strategize their business more effectively. By offering personalized products and services, retailers can create a sense of exclusivity and value for their subscribers, leading to increased customer retention and lifetime value. Additionally, subscriptions provide valuable data insights that can be used to optimize the customer experience and tailor offerings to meet the evolving needs of the target audience.
# prompt:   <prompt> Discuss the role of personalization in subscription-based businesses.
# answer:   <ans> Personalization plays a crucial role in subscription-based businesses as it helps to create a unique and tailored experience for each subscriber. By leveraging data insights and customer preferences, businesses can curate personalized content, products, and services that align with the individual needs and interests of their subscribers. This level of personalization fosters a deeper connection between the business and its customers, leading to increased customer satisfaction, loyalty, and retention. Furthermore, personalization can drive higher engagement rates, encourage repeat purchases, and ultimately contribute to the growth and success of the subscription-based business.
# prompt:   <prompt> How can businesses leverage cancellation insights to improve their subscription model?
# answer:   <ans> Businesses can leverage cancellation insights to improve their subscription model by gaining a deeper understanding of customer behavior, preferences, and reasons for cancellation. By analyzing cancellation data, businesses can identify patterns and trends that may indicate areas for improvement in their subscription offerings, pricing, or communication strategies. This information can be used to refine the value proposition, enhance the customer experience, and address any pain points that may lead to cancellations. Additionally, cancellation insights can help businesses identify potential churn risks and proactively implement strategies to retain customers, such as targeted retention campaigns, personalized offers, and improved customer support.
# prompt:   <prompt> What strategies can be employed to retain subscribers in the face of increasing cancellations?
# answer:   <ans> To retain subscribers in the face of increasing cancellations, businesses can employ several strategies. Firstly, they can focus on improving the overall customer experience by providing high-quality products or services, personalized content, and excellent customer support. Secondly, businesses can implement targeted retention campaigns, such as offering exclusive discounts, rewards, or early access to new products or services, to incentivize subscribers to stay. Thirdly, businesses can leverage data insights to understand the reasons behind cancellations and address those pain points directly. This may involve refining the subscription model, adjusting pricing, or enhancing communication channels. Lastly, businesses can foster a sense of community and engagement among subscribers through social media, forums, or events, creating a stronger connection and sense of belonging that encourages loyalty and retention.
# prompt:   <prompt> How can businesses effectively communicate with their subscribers to minimize cancellations?
# answer:   <ans> Businesses can effectively communicate with their subscribers to minimize cancellations by implementing a proactive and transparent communication strategy. This includes providing clear and concise information about the subscription terms, benefits, and any changes to the service. Regular updates and reminders about upcoming renewals or new features can also help keep subscribers engaged and informed. Additionally, businesses can leverage personalized communication channels, such as email newsletters, social media, or mobile apps, to deliver tailored content and offers that resonate with subscribers' interests and preferences. By fostering open and ongoing dialogue, businesses can build trust, address concerns, and strengthen the relationship with their subscribers, ultimately reducing the likelihood of cancellations.
# prompt:   <prompt> What are some best practices for businesses to comply with the FTC's Click-to-Cancel Rule while retaining subscribers?
# answer:   <ans> To comply with the FTC's Click-to-Cancel Rule while retaining subscribers, businesses can adopt several best practices. Firstly, they should ensure that the cancellation process is easily accessible and clearly communicated to subscribers, with a prominent link or button that allows them to opt-out of receiving further communications. Secondly, businesses should provide a clear and concise explanation of the consequences of cancellation, such as the loss of access to certain features or benefits. Thirdly, businesses can offer incentives or benefits for subscribers who choose to stay, such as exclusive discounts, early access to new products, or personalized recommendations. Additionally, businesses should regularly review and update their cancellation policies and procedures to ensure compliance with the FTC's guidelines and maintain transparency with their subscribers.
# prompt:   <prompt> How can businesses use AI to leverage cancellation insights and improve their subscription model?
# answer:   <ans> Businesses can use AI to leverage cancellation insights and improve their subscription model by harnessing the power of data analytics and machine learning algorithms. AI can help businesses analyze large volumes of cancellation data to identify patterns, trends, and correlations that may indicate the underlying reasons for cancellations. By understanding these insights, businesses can make data-driven decisions to optimize their subscription offerings, pricing, and communication strategies. AI can also be used to develop predictive models that forecast potential churn risks, allowing businesses to proactively implement retention strategies and personalized offers. Furthermore, AI-powered chatbots or virtual assistants can provide real-time support and assistance to subscribers, addressing their concerns and queries promptly, thereby enhancing the overall customer experience and reducing the likelihood of cancellations.
# prompt:   <prompt> What are some effective strategies for businesses to foster customer loyalty and retention in their subscription-based businesses?
# answer:   <ans> To foster customer loyalty and retention in their subscription-based businesses, businesses can implement several effective strategies. Firstly, they can focus on delivering exceptional customer experiences by consistently providing high-quality products or services, personalized content, and excellent customer support. Secondly, businesses can implement loyalty programs or
# prompt:   <prompt>Identify and list the key financial metrics mentioned in the text, providing a brief explanation for each metric's significance in financial analysis.</ans>
# prompt:   <prompt>Extract and summarize the main process described in the text, focusing on its purpose and the steps involved.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be applied, detailing the potential outcomes and implications.</ans>
# prompt:   <prompt>Outline the potential risks and challenges that could be associated with the data or process described in the text.</ans>
# prompt:   <prompt>Generate a list of possible industry applications for the described data, explaining how it could be utilized in each industry.</ans>
# prompt:   <prompt>Propose a research question that could be explored further based on the information provided in the text.</ans>
# prompt:   <prompt>Describe a potential trend or pattern that could be inferred from the data mentioned in the text, including its possible causes and effects.</ans>
# prompt:   <prompt>Suggest a method for visualizing the data described in the text, explaining how it could enhance understanding and decision-making.</ans>
# prompt:   <prompt>Develop a set of criteria for evaluating the effectiveness of the process or metric described in the text.</ans>
# prompt:   <prompt>Imagine a competitive analysis based on the data provided; identify key competitors and how they might be performing relative to the described data.</ans>
# prompt:   <prompt>Propose a strategic initiative that could be developed using the data or process described in the text, detailing the expected benefits and challenges.</ans>
# prompt:   <prompt>Outline the potential impact of the described data on stakeholders, including customers, investors, and employees.</ans>
# prompt:   <prompt>Design a survey or questionnaire that could be used to gather additional data related to the topic discussed in the text.</ans>
# prompt:   <prompt>Create a hypothetical case study that applies the described data or process, illustrating its practical use and potential benefits.</ans>
# prompt:   <prompt>Suggest a method for collecting additional data that could complement the information provided in the text, enhancing its value for analysis.</ans>
# prompt:   <prompt>Propose a training or educational program that could be developed to help others understand and apply the described data or process effectively.</ans>
# prompt:   <prompt>Identify potential future developments or advancements that could be made in the area described by the text, considering current trends and technologies.</ans>
# prompt:   <prompt>Develop a risk management plan that addresses the potential risks associated with the data or process described in the text.</ans>
# prompt:   <prompt>Create a hypothetical scenario where the described data could be used to inform policy decisions, detailing the decision-making process and expected outcomes.</ans>
# ...
# prompt:   <prompt> Discuss the rationale behind the individual's decision to seek funding despite being a one-man show with a profitable business.
# answer:   <ans> The individual's decision to seek funding, despite being a one-man show with a profitable business, was driven by the desire to grow faster and larger by hiring more people to build a more full-featured product. This would, in turn, attract more customers and create a positive snowball effect for the business. Additionally, the funding would provide the necessary resources to expand the business and reach new markets, ultimately increasing its profitability and long-term success. The investor's support and agreement to the terms set by the individual also played a role in this decision, as it allowed the individual to maintain control over their business while still securing the necessary funding to achieve their growth goals.
# prompt:   <prompt> Identify the key factors that led to the successful funding round.
# answer:   <ans> The successful funding round was primarily driven by the individual's unique position as a one-man show with a fast-growing business and very little overhead. The individual's clear criteria for the types of deals they were interested in, and their ability to find an investor, General Catalyst, who aligned with their vision and terms, were also key factors. General Catalyst's perspective and experience in certain markets likely contributed to their willingness to agree to the terms set by the individual. The successful funding round, which resulted in a 500,000 round of funding with favorable terms, allowed the individual to maintain control over their business while still securing the necessary resources to grow and expand.
# prompt:   <prompt> Explain the investor's perspective and how it influenced the funding round.
# answer:   <ans> The investor, General Catalyst, had a perspective that aligned with the individual's vision and terms for the funding round. They were willing to agree to the terms set by the individual, which included not giving up board seats or a significant amount of equity. This perspective allowed the individual to maintain control over their business and its direction, while still securing the necessary funding to grow their business. General Catalyst's perspective and experience in certain markets likely contributed to their willingness to agree to these terms, as they understood the potential for the individual's business to succeed and grow. This alignment of perspectives between the investor and the individual played a significant role in the success of the funding round.
# prompt:   <prompt> Discuss the benefits of the funding round for the individual's business.
# answer:   <ans> The funding round provided several benefits for the individual's business. Firstly, it allowed the individual to maintain control over their business and its direction, as they were able to set the terms for the funding round and find an investor, General Catalyst, who aligned with their vision. Secondly, the funding provided the necessary resources to grow and expand the business, allowing the individual to hire more people to build a more full-featured product. This would, in turn, attract more customers and create a positive snowball effect for the business. Additionally, the funding would provide the necessary resources to expand the business and reach new markets, ultimately increasing its profitability and long-term success. Overall, the funding round allowed the individual to achieve their growth goals while maintaining control over their business.
# prompt:   <prompt> Provide a list of key financial terms and their definitions.
# answer:   <ans> Key financial terms and their definitions:
# prompt:   <prompt> Identify the key factors that contribute to the success of a subscription-based business model.
# answer:   <ans> The key factors that contribute to the success of a subscription-based business model include a strong value proposition, a user-friendly onboarding process, effective customer retention strategies, and a diverse range of subscription tiers to cater to different customer needs. Additionally, leveraging data analytics to understand customer behavior and preferences can help businesses optimize their subscription offerings and improve customer satisfaction.
# prompt:   <prompt> Suggest strategies to improve customer retention in a subscription-based business.
# answer:   <ans> To improve customer retention in a subscription-based business, businesses can implement strategies such as providing personalized content and recommendations, offering exclusive perks and discounts to long-term subscribers, implementing a robust customer support system, and regularly seeking customer feedback to identify areas for improvement. Additionally, implementing a seamless onboarding process and continuously innovating and updating the product or service can help keep customers engaged and satisfied with their subscription.
# prompt:   <prompt> Explain the importance of data analytics in managing a subscription-based business.
# answer:   <ans> Data analytics plays a crucial role in managing a subscription-based business by providing insights into customer behavior, preferences, and churn rates. By analyzing data, businesses can identify patterns and trends, allowing them to make data-driven decisions to optimize their subscription offerings, improve customer retention, and increase customer lifetime value. Furthermore, data analytics can help businesses identify upsell and cross-sell opportunities, enabling them to tailor their marketing and communication strategies to individual customer needs and preferences. Overall, data analytics empowers businesses to make informed decisions and continuously improve their subscription-based business model.
# prompt:   <prompt> Provide a list of the key factors influencing the growth of SaaS businesses mentioned in the text.
# answer:   <ans> The key factors influencing the growth of SaaS businesses mentioned in the text are:
# prompt:   <prompt> Provide a list of the key responsibilities and qualities sought in the hiring process described in the text.
# answer:   <ans> The key responsibilities and qualities sought in the hiring process described in the text include:
# prompt:   <prompt> Describe the impact of a significant new feature release on customer perception and feedback.
# answer:   <ans> The release of a significant new feature had a positive impact on customer perception and feedback. After addressing the primary issue of lack of progress, the percentage of Passives increased significantly, indicating improved customer confidence in the company. This demonstrates the importance of actively addressing customer concerns and continuously improving the product to maintain a positive perception.
# prompt:   <prompt> Explain the relationship between addressing customer concerns and the Net Promoter Score (NPS) results.
# answer:   <ans> Addressing customer concerns directly correlates with improved Net Promoter Score (NPS) results. In the given scenario, the company's efforts to tackle performance issues and perceived lack of progress led to a decrease in Detractors and an increase in Passives. This improvement in NPS reflects the positive impact of addressing customer concerns on overall customer satisfaction and loyalty.
# prompt:   <prompt> Identify the key factors that contributed to the company's improved performance and customer satisfaction.
# answer:   <ans> The key factors that contributed to the company's improved performance and customer satisfaction include the release of a significant new feature, addressing performance issues, and actively working to improve the product. By directly addressing customer concerns and continuously improving the product, the company was able to increase customer confidence and satisfaction, as evidenced by the improved NPS results. Additionally, the company's dedication to tackling issues and making necessary changes demonstrated their commitment to customer success.
# prompt:   <prompt> Explain the key features of a tool that aids in customer retention for subscription-based businesses.
# answer:   <ans> The key features of Chargebee Retention, a tool that aids in customer retention for subscription-based businesses, include AI-powered personalized offers, real-time delivery of professional-grade copy, intelligent scaling for subscription businesses, and the ability to transform potential churn into lasting engagement and loyalty. This tool leverages advanced AI to streamline the offer creation process, enabling businesses to respond quickly and effectively to customer needs. Additionally, Chargebee Retention ensures every offer contributes to enhanced customer satisfaction and business success, making it a strategic tool for subscription-based businesses.
# prompt:   <prompt> Describe the benefits of using an AI-powered tool for managing customer retention in subscription-based businesses.
# answer:   <ans> Using an AI-powered tool like Chargebee Retention for managing customer retention in subscription-based businesses offers several benefits. Firstly, it enables businesses to create and deploy effective retention offers rapidly, bypassing traditional slow methodologies that require extensive collaboration with copywriters and data analysts. Secondly, the tool provides personalized and tailored subscription offers, leveraging advanced AI to ensure each customer feels valued and engaged. This leads to a reduction in churn rates and an increase in customer loyalty. Thirdly, the tool's intelligent scaling feature allows businesses to scale their customer retention efforts efficiently, ensuring that the right amount of resources is allocated to meet the unique needs of their customers. Lastly, Chargebee Retention's commitment to innovation and continuous integration of the latest in machine learning (ML) ensures that businesses stay ahead of the curve and maintain a competitive edge in the market.
# prompt:   <prompt> What are the challenges faced by subscription-based businesses in creating and deploying effective retention offers, and how does an AI-powered tool address these challenges?
# answer:   <ans> Subscription-based businesses often face challenges in rapidly creating and deploying effective retention offers due to uncertainty about which types of offers will perform best and how to tailor these offers to the unique contexts of their customers. Traditional methodologies that require extensive collaboration with copywriters and data analysts, along with significant time investments, can further complicate the process. An AI-powered tool like Chargebee Retention addresses these challenges by leveraging advanced AI to personalize offers, streamlining the offer creation process significantly. This enables businesses to respond quickly and effectively to customer needs, while also ensuring that each offer is tailored to the specific context of the customer, leading to higher engagement and reduced churn rates. Additionally, the tool's intelligent scaling feature allows businesses to scale their customer retention efforts efficiently, ensuring that the right amount of resources is allocated to meet the unique needs of their customers.
# prompt:   <prompt> How does Chargebee Retention's AI-powered tool contribute to enhancing customer satisfaction and business success?
# answer:   <ans> Chargebee Retention's AI-powered tool contributes to enhancing customer satisfaction and business success in several ways. Firstly, the tool enables businesses to create and deploy personalized and tailored retention offers, ensuring that each customer feels valued and engaged. This leads to increased customer satisfaction and loyalty, reducing churn rates and increasing customer retention. Secondly, the tool's intelligent scaling feature allows businesses to allocate the right amount of resources to meet the unique needs of their customers, ensuring that they receive the best possible service and support. This leads to improved customer experiences and increased business success. Lastly, Chargebee Retention's commitment to innovation and continuous integration of the latest in machine learning (ML) ensures that businesses stay ahead of the curve and maintain a competitive edge in the market, further contributing to business success.
# prompt:   <prompt> Explain the importance of separating expenses into distinct categories for financial analysis.
# answer:   <ans> Separating expenses into distinct categories is crucial for financial analysis as it allows for a more detailed and accurate understanding of where the company's money is being spent. This level of granularity enables businesses to identify trends, track performance against budgets, and make informed decisions about future investments. For instance, by categorizing expenses into Sales, Marketing, and Engineering, a company can easily determine the effectiveness of its sales strategies, marketing campaigns, and engineering efforts. This detailed breakdown also facilitates benchmarking against industry standards, ensuring that the company is investing appropriately in its key areas of focus. Ultimately, separating expenses into distinct categories enhances financial transparency and aids in strategic decision-making.
# prompt:   <prompt> Describe the process of setting up a Sales & Marketing account for financial tracking.
# answer:   <ans> Setting up a Sales & Marketing account for financial tracking involves creating a dedicated account within the company's chart of accounts to capture all related expenses. This process typically begins by establishing a Sales & Marketing category under the broader Expenses category. Within this category, various sub-accounts can be created to house individual expense accounts, such as Sales Payroll, Advertising, Conferences, and Marketing Solutions. By doing so, the company can easily monitor and analyze the costs associated with its sales and marketing efforts. Additionally, it is recommended to further separate expenses into specific activities, such as Sales Executives, Sales Development Representatives, and Sales Travel, to gain a more detailed understanding of where the company's resources are being allocated. This structured approach to financial tracking enables businesses to assess the effectiveness of their sales and marketing strategies, identify areas for improvement, and make data-driven decisions to optimize their financial performance.
# prompt:   <prompt> Discuss the benefits of separating Engineering expenses from General & Admin expenses.
# answer:   <ans> Separating Engineering expenses from General & Admin (G&A) expenses offers several benefits for financial analysis and management. Firstly, it allows businesses to gain a clearer understanding of the proportion of their total expenses dedicated to engineering activities. This information can be used to benchmark against industry standards and competitors, providing insights into the company's investment in its technical capabilities. Secondly, by tracking Engineering expenses separately, businesses can identify trends and patterns in spending, enabling them to make informed decisions about resource allocation and budgeting. For example, if the company notices a significant increase in Engineering expenses, it can investigate the underlying causes and determine whether additional investments are necessary or if there are areas where costs can be optimized. Furthermore, a detailed breakdown of Engineering expenses helps businesses track their performance against the budget, ensuring that they are effectively managing their resources and making the most efficient use of their funds. Overall, separating Engineering expenses from G&A expenses enhances financial transparency, facilitates strategic decision-making, and supports the long-term success of a technology-focused company.

# %%
len(prompts)
# Out:
# 1096

# %%
len(answers)
# Out:
# 1096

# %%
prompts[1001]
# Out:
# '  <prompt> Identify the different types of subscription models mentioned in the text and provide a brief description of each.'

# %%
answers[1001]
# Out:
# '  <ans> The text mentions three main types of subscription models: Sampling Subscriptions, Bargain Subscriptions, and Consumables Subscriptions. Sampling Subscriptions involve companies curating and sending items to customers based on their preferences, with the aim of sustaining growth through variety and low prices. Bargain Subscriptions focus on offering products at discounted prices, allowing customers to skip or cancel the subscription at any time. Consumables Subscriptions are centered around consumable products, providing customers with discounts and additional products as their supplies run out. These models highlight the importance of value proposition and sustainable growth in subscription businesses.'

# %%
df = pd.DataFrame({"prompts": prompts, "answers": answers})

# %%
df
# Out:
#                                                prompts  \
# 0      <prompt> Identify and describe the key facto...
# 1      <prompt> Explain the importance of a seamles...
# 2      <prompt> Discuss the potential risks and cha...
# 3      <prompt> Describe the benefits of using AI-d...
# 4      <prompt> Explain the role of eInvoicing in n...
# ..                                                 ...
# 734    <prompt>Explain how Chargebee's automation a...
# 735    <prompt> Explain the professional background...
# 736    <prompt> Identify the strategies mentioned i...
# 737    <prompt> Describe the benefits of subscribin...
# 738    <prompt> Explain the concept of SaaS pricing...
#
#                                                answers
# 0      <ans> Key factors that contribute to success...
# 1      <ans> A seamless checkout experience is cruc...
# 2      <ans> Homegrown billing systems may face cha...
# 3      <ans> AI-driven offers can help subscription...
# 4      <ans> EInvoicing plays a crucial role in nav...
# ..                                                 ...
# 734    <ans>Chargebee's automation and integrative ...
# 735    <ans> The individual mentioned in the text, ...
# 736    <ans> The text mentions six proven strategie...
# 737    <ans> Subscribing to the source mentioned in...
# 738    <ans> SaaS pricing models refer to the vario...
#
# [739 rows x 2 columns]

# %%
df = df.replace("", np.nan)

# %%
df = df.dropna()

# %%
login(token="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")

# %%
df.to_csv("data/nyx-finance-instruct.csv", index=False)

# %%
dataset = Dataset.from_csv("data/nyx-finance-instruct.csv")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset.push_to_hub("Core-Outline/nyx-finance-instruct")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/308 [00:00<?, ?B/s]
# C:\Users\tsuma.thomas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\tsuma.thomas\.cache\huggingface\hub\datasets--Core-Outline--nyx-finance-instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# CommitInfo(commit_url='https://huggingface.co/datasets/core-outline/nyx-finance-instruct/commit/94e06c2f724a19089cacab77ac8342ddff72c44e', commit_message='Upload dataset', commit_description='', oid='94e06c2f724a19089cacab77ac8342ddff72c44e', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/core-outline/nyx-finance-instruct', endpoint='https://huggingface.co', repo_type='dataset', repo_id='core-outline/nyx-finance-instruct'), pr_revision=None, pr_num=None)

# %%
def formatData(entry):
    print(entry)
    instruction_text = (
        f"Below is an instruction that describes a task. "
        f"Write a response that appropriately completes the request."
        f"\n\n ### Instruction:\n{entry['prompts'].strip().replace('<prompt>','').replace('</prompt>','')}"
    )
    input_text = (
        f"\n\n### Input: \n{entry['input'].strip()}" if "input" in entry else ""
    )

    desired_response = f"\n\n### Response: \n{entry['answers'].strip().replace('<ans>','').replace('</ans>','')}"

    return instruction_text + input_text + desired_response

def format_input(entry):
    print(entry)
    instruction_text = (
        f"Below is an instruction that describes a task. "
        f"Write a response that appropriately completes the request."
        f"\n\n ### Instruction:\n{entry['prompts'].strip().replace('<prompt>','').replace('</prompt>','')}"
    )
    input_text = (
        f"\n\n### Input: \n{entry['input'].strip()}" if "input" in entry else ""
    )


    return instruction_text + input_text

# %%
df['llm_input'] = df.apply(formatData, axis=1)
# Out:
# prompts      <prompt> Identify and describe the key facto...
# answers      <ans> Key factors that contribute to success...
# Name: 0, dtype: object
# prompts      <prompt> Explain the importance of a seamles...
# answers      <ans> A seamless checkout experience is cruc...
# Name: 1, dtype: object
# prompts      <prompt> Discuss the potential risks and cha...
# answers      <ans> Homegrown billing systems may face cha...
# Name: 2, dtype: object
# prompts      <prompt> Describe the benefits of using AI-d...
# answers      <ans> AI-driven offers can help subscription...
# Name: 3, dtype: object
# prompts      <prompt> Explain the role of eInvoicing in n...
# answers      <ans> EInvoicing plays a crucial role in nav...
# Name: 4, dtype: object
# prompts      <prompt> Discuss the impact of subscription ...
# answers      <ans> Subscription growth can significantly ...
# Name: 5, dtype: object
# prompts      <prompt> Explain the concept of subscription...
# answers      <ans> Subscription ramps refer to the strate...
# Name: 6, dtype: object
# prompts      <prompt> Discuss the best practices for a se...
# answers      <ans> Best practices for a seamless billing ...
# Name: 7, dtype: object
# prompts      <prompt> Explain the significance of the Gar...
# answers      <ans> The Gartner Magic Quadrant for Recurri...
# Name: 8, dtype: object
# prompts      <prompt> Discuss the potential growth opport...
# answers      <ans> Potential growth opportunities for sub...
# Name: 9, dtype: object
# prompts      <prompt> Explain the concept of subscription...
# answers      <ans> Subscription entitlement management re...
# Name: 10, dtype: object
# prompts      <prompt> Explain the importance of subscript...
# answers      <ans> The importance of subscriptions for re...
# Name: 11, dtype: object
# prompts      <prompt> Discuss the role of personalization...
# answers      <ans> Personalization plays a crucial role i...
# Name: 12, dtype: object
# prompts      <prompt> How can businesses leverage cancell...
# answers      <ans> Businesses can leverage cancellation i...
# Name: 13, dtype: object
# prompts      <prompt> What strategies can be employed to ...
# answers      <ans> To retain subscribers in the face of i...
# Name: 14, dtype: object
# prompts      <prompt> Identify and describe the key facto...
# answers      <ans> Key factors that contribute to success...
# Name: 15, dtype: object
# prompts      <prompt> Explain the importance of a seamles...
# answers      <ans> A seamless checkout experience is cruc...
# Name: 16, dtype: object
# prompts      <prompt> Discuss the potential risks and cha...
# answers      <ans> Homegrown billing systems may face cha...
# Name: 17, dtype: object
# prompts      <prompt> Describe the benefits of using AI-d...
# answers      <ans> AI-driven offers can help subscription...
# Name: 18, dtype: object
# prompts      <prompt> Explain the role of eInvoicing in n...
# answers      <ans> EInvoicing plays a crucial role in nav...
# Name: 19, dtype: object
# prompts      <prompt> Discuss the impact of subscription ...
# answers      <ans> Subscription growth can significantly ...
# Name: 20, dtype: object
# prompts      <prompt> Explain the concept of subscription...
# answers      <ans> Subscription ramps refer to the strate...
# Name: 21, dtype: object
# prompts      <prompt> Discuss the best practices for a se...
# answers      <ans> Best practices for a seamless billing ...
# Name: 22, dtype: object
# prompts      <prompt> Explain the significance of the Gar...
# answers      <ans> The Gartner Magic Quadrant for Recurri...
# Name: 23, dtype: object
# prompts      <prompt> Discuss the potential growth opport...
# answers      <ans> Potential growth opportunities for sub...
# Name: 24, dtype: object
# prompts      <prompt> Explain the concept of subscription...
# answers      <ans> Subscription entitlement management re...
# Name: 25, dtype: object
# prompts      <prompt> Explain the importance of subscript...
# answers      <ans> The importance of subscriptions for re...
# Name: 26, dtype: object
# prompts      <prompt> Discuss the role of personalization...
# answers      <ans> Personalization plays a crucial role i...
# Name: 27, dtype: object
# prompts      <prompt> How can businesses leverage cancell...
# answers      <ans> Businesses can leverage cancellation i...
# Name: 28, dtype: object
# prompts      <prompt> What strategies can be employed to ...
# answers      <ans> To retain subscribers in the face of i...
# Name: 29, dtype: object
# prompts      <prompt> How can businesses effectively comm...
# answers      <ans> Businesses can effectively communicate...
# Name: 30, dtype: object
# prompts      <prompt> What are some best practices for bu...
# answers      <ans> To comply with the FTC's Click-to-Canc...
# Name: 31, dtype: object
# prompts      <prompt> How can businesses use AI to levera...
# answers      <ans> Businesses can use AI to leverage canc...
# Name: 32, dtype: object
# prompts      <prompt> What are some effective strategies ...
# answers      <ans> To foster customer loyalty and retenti...
# Name: 33, dtype: object
# prompts      <prompt>Identify the key financial benefits ...
# answers      <ans>The key financial benefits mentioned in...
# Name: 84, dtype: object
# prompts      <prompt>Extract the various roles and titles...
# answers      <ans>The various roles and titles mentioned ...
# Name: 85, dtype: object
# prompts      <prompt>Identify the different types of inte...
# answers      <ans>The text mentions integrated payment ga...
# Name: 86, dtype: object
# prompts      <prompt>Extract the geographical scope of Ch...
# answers      <ans>Chargebee serves customers in 6,500 mer...
# Name: 87, dtype: object
# prompts      <prompt>Identify the specific features and c...
# answers      <ans>The text highlights features and capabi...
# Name: 88, dtype: object
# prompts      <prompt>Extract the various benefits and out...
# answers      <ans>Companies using Chargebee have experien...
# Name: 89, dtype: object
# prompts      <prompt>Identify the different types of even...
# answers      <ans>The text mentions events and resources ...
# Name: 90, dtype: object
# prompts      <prompt>Extract the various aspects of Charg...
# answers      <ans>Chargebee's product offerings include a...
# Name: 91, dtype: object
# prompts      <prompt>Identify the different types of cust...
# answers      <ans>The text mentions resources such as the...
# Name: 92, dtype: object
# prompts      <prompt>Extract the various types of integra...
# answers      <ans>The text mentions integrated payment ga...
# Name: 93, dtype: object
# prompts      <prompt>Identify the different types of fina...
# answers      <ans>The text mentions financial metrics and...
# Name: 94, dtype: object
# prompts      <prompt>Extract the various types of custome...
# answers      <ans>The text mentions features and capabili...
# Name: 95, dtype: object
# prompts      <prompt>Identify the different types of even...
# answers      <ans>The text mentions events and resources ...
# Name: 96, dtype: object
# prompts      <prompt>Extract the various types of financi...
# answers      <ans>The text mentions financial benefits an...
# Name: 97, dtype: object
# prompts      <prompt> Identify and describe the key facto...
# answers      <ans> Key factors that contribute to success...
# Name: 98, dtype: object
# prompts      <prompt> Explain the importance of a seamles...
# answers      <ans> A seamless checkout experience is cruc...
# Name: 99, dtype: object
# prompts      <prompt> Discuss the potential risks and cha...
# answers      <ans> Homegrown billing systems may face cha...
# Name: 100, dtype: object
# prompts      <prompt> Describe the benefits of using AI-d...
# answers      <ans> AI-driven offers can help subscription...
# Name: 101, dtype: object
# prompts      <prompt> Explain the role of eInvoicing in n...
# answers      <ans> EInvoicing plays a crucial role in nav...
# Name: 102, dtype: object
# prompts      <prompt> Discuss the impact of subscription ...
# answers      <ans> Subscription growth can significantly ...
# Name: 103, dtype: object
# prompts      <prompt> Explain the concept of subscription...
# answers      <ans> Subscription ramps refer to the strate...
# Name: 104, dtype: object
# prompts      <prompt> Discuss the best practices for a se...
# answers      <ans> Best practices for a seamless billing ...
# Name: 105, dtype: object
# prompts      <prompt> Explain the significance of the Gar...
# answers      <ans> The Gartner Magic Quadrant for Recurri...
# Name: 106, dtype: object
# prompts      <prompt> Discuss the potential growth opport...
# answers      <ans> Potential growth opportunities for sub...
# Name: 107, dtype: object
# prompts      <prompt> Explain the concept of subscription...
# answers      <ans> Subscription entitlement management re...
# Name: 108, dtype: object
# prompts      <prompt> Explain the importance of subscript...
# answers      <ans> The importance of subscriptions for re...
# Name: 109, dtype: object
# prompts      <prompt> Discuss the role of personalization...
# answers      <ans> Personalization plays a crucial role i...
# Name: 110, dtype: object
# prompts      <prompt> How can businesses leverage cancell...
# answers      <ans> Businesses can leverage cancellation i...
# Name: 111, dtype: object
# prompts      <prompt> What strategies can be employed to ...
# answers      <ans> To retain subscribers in the face of i...
# Name: 112, dtype: object
# prompts      <prompt> How can businesses effectively comm...
# answers      <ans> Businesses can effectively communicate...
# Name: 113, dtype: object
# prompts      <prompt> What are some best practices for bu...
# answers      <ans> To comply with the FTC's Click-to-Canc...
# Name: 114, dtype: object
# prompts      <prompt> How can businesses use AI to levera...
# answers      <ans> Businesses can use AI to leverage canc...
# Name: 115, dtype: object
# prompts      <prompt> What are some effective strategies ...
# answers      <ans> To foster customer loyalty and retenti...
# Name: 116, dtype: object
# prompts      <prompt>Identify the key financial benefits ...
# answers      <ans>The key financial benefits mentioned in...
# Name: 167, dtype: object
# prompts      <prompt>Extract the various roles and titles...
# answers      <ans>The various roles and titles mentioned ...
# Name: 168, dtype: object
# prompts      <prompt>Identify the different types of inte...
# answers      <ans>The text mentions integrated payment ga...
# Name: 169, dtype: object
# prompts      <prompt>Extract the geographical scope of Ch...
# answers      <ans>Chargebee serves customers in 6,500 mer...
# Name: 170, dtype: object
# prompts      <prompt>Identify the specific features and c...
# answers      <ans>The text highlights features and capabi...
# Name: 171, dtype: object
# prompts      <prompt>Extract the various benefits and out...
# answers      <ans>Companies using Chargebee have experien...
# Name: 172, dtype: object
# prompts      <prompt>Identify the different types of even...
# answers      <ans>The text mentions events and resources ...
# Name: 173, dtype: object
# prompts      <prompt>Extract the various aspects of Charg...
# answers      <ans>Chargebee's product offerings include a...
# Name: 174, dtype: object
# prompts      <prompt>Identify the different types of cust...
# answers      <ans>The text mentions resources such as the...
# Name: 175, dtype: object
# prompts      <prompt>Extract the various types of integra...
# answers      <ans>The text mentions integrated payment ga...
# Name: 176, dtype: object
# prompts      <prompt>Identify the different types of fina...
# answers      <ans>The text mentions financial metrics and...
# Name: 177, dtype: object
# prompts      <prompt>Extract the various types of custome...
# answers      <ans>The text mentions features and capabili...
# Name: 178, dtype: object
# prompts      <prompt>Identify the different types of even...
# answers      <ans>The text mentions events and resources ...
# Name: 179, dtype: object
# prompts      <prompt>Extract the various types of financi...
# answers      <ans>The text mentions financial benefits an...
# Name: 180, dtype: object
# prompts      <prompt> Identify and describe the key facto...
# answers      <ans> Key factors that contribute to success...
# Name: 181, dtype: object
# prompts      <prompt> Explain the importance of a seamles...
# answers      <ans> A seamless checkout experience is cruc...
# Name: 182, dtype: object
# prompts      <prompt> Discuss the potential risks and cha...
# answers      <ans> Homegrown billing systems may face cha...
# Name: 183, dtype: object
# prompts      <prompt> Describe the benefits of using AI-d...
# answers      <ans> AI-driven offers can help subscription...
# Name: 184, dtype: object
# prompts      <prompt> Explain the role of eInvoicing in n...
# answers      <ans> EInvoicing plays a crucial role in nav...
# Name: 185, dtype: object
# prompts      <prompt> Discuss the impact of subscription ...
# answers      <ans> Subscription growth can significantly ...
# Name: 186, dtype: object
# prompts      <prompt> Explain the concept of subscription...
# answers      <ans> Subscription ramps refer to the strate...
# Name: 187, dtype: object
# prompts      <prompt> Discuss the best practices for a se...
# answers      <ans> Best practices for a seamless billing ...
# Name: 188, dtype: object
# prompts      <prompt> Explain the significance of the Gar...
# answers      <ans> The Gartner Magic Quadrant for Recurri...
# Name: 189, dtype: object
# prompts      <prompt> Discuss the potential growth opport...
# answers      <ans> Potential growth opportunities for sub...
# Name: 190, dtype: object
# prompts      <prompt> Explain the concept of subscription...
# answers      <ans> Subscription entitlement management re...
# Name: 191, dtype: object
# prompts      <prompt> Explain the importance of subscript...
# answers      <ans> The importance of subscriptions for re...
# Name: 192, dtype: object
# prompts      <prompt> Discuss the role of personalization...
# answers      <ans> Personalization plays a crucial role i...
# Name: 193, dtype: object
# prompts      <prompt> How can businesses leverage cancell...
# answers      <ans> Businesses can leverage cancellation i...
# Name: 194, dtype: object
# prompts      <prompt> What strategies can be employed to ...
# answers      <ans> To retain subscribers in the face of i...
# Name: 195, dtype: object
# prompts      <prompt> How can businesses effectively comm...
# answers      <ans> Businesses can effectively communicate...
# Name: 196, dtype: object
# prompts      <prompt> What are some best practices for bu...
# answers      <ans> To comply with the FTC's Click-to-Canc...
# Name: 197, dtype: object
# prompts      <prompt> How can businesses use AI to levera...
# answers      <ans> Businesses can use AI to leverage canc...
# Name: 198, dtype: object
# prompts      <prompt> What are some effective strategies ...
# answers      <ans> To foster customer loyalty and retenti...
# Name: 199, dtype: object
# prompts      <prompt> Outline the key skills and expertis...
# answers      <ans> A professional in the field of event s...
# Name: 250, dtype: object
# prompts      <prompt> Explain the concept of customer lif...
# answers      <ans> Customer lifetime value refers to the ...
# Name: 251, dtype: object
# prompts      <prompt> Describe the importance of personal...
# answers      <ans> Personalization in subscription models...
# Name: 252, dtype: object
# prompts      <prompt> Discuss the role of event strategy ...
# answers      <ans> Event strategy plays a vital role in d...
# Name: 253, dtype: object
# prompts      <prompt> Explain the concept of 'subscriptio...
# answers      <ans> Subscription alchemy refers to the pro...
# Name: 254, dtype: object
# prompts      <prompt> Discuss the impact of localization ...
# answers      <ans> Localization plays a crucial role in i...
# Name: 255, dtype: object
# prompts      <prompt> Explain the significance of strateg...
# answers      <ans> Strategic partnerships play a signific...
# Name: 256, dtype: object
# prompts      <prompt> Discuss the importance of optimizin...
# answers      <ans> Optimizing ticket sales is crucial in ...
# Name: 257, dtype: object
# prompts      <prompt> Explain the impact of the psycholog...
# answers      <ans> The psychology of subscriptions plays ...
# Name: 258, dtype: object
# prompts      <prompt> Discuss the impact of self-serve ca...
# answers      <ans> Self-serve cancellations can have a si...
# Name: 259, dtype: object
# prompts      <prompt> Explain the concept of 'event strat...
# answers      <ans> Event strategy refers to the planning ...
# Name: 260, dtype: object
# prompts      <prompt> Discuss the impact of the subscript...
# answers      <ans> The subscription revenue impact of cus...
# Name: 261, dtype: object
# prompts      <prompt> Explain the concept of 'subscriptio...
# answers      <ans> Subscription alchemy refers to the pro...
# Name: 262, dtype: object
# prompts      <prompt> Identify and describe the key facto...
# answers      <ans> Key factors contributing to the succes...
# Name: 263, dtype: object
# prompts      <prompt> Explain the importance of integrati...
# answers      <ans> Integrating payment gateways with subs...
# Name: 264, dtype: object
# prompts      <prompt> Discuss the potential risks associa...
# answers      <ans> Homegrown billing systems can pose hid...
# Name: 265, dtype: object
# prompts      <prompt> How can subscription management imp...
# answers      <ans> Subscription management can boost a sa...
# Name: 266, dtype: object
# prompts      <prompt> What are the benefits of a seamless...
# answers      <ans> A seamless billing system migration ca...
# Name: 267, dtype: object
# prompts      <prompt> How can subscription ramps be used ...
# answers      <ans> Subscription ramps can be used to driv...
# Name: 268, dtype: object
# prompts      <prompt> What are the key components of a co...
# answers      <ans> Key components of a compliant billing ...
# Name: 269, dtype: object
# prompts      <prompt> How can subscription-based business...
# answers      <ans> Subscription-based businesses can leve...
# Name: 270, dtype: object
# prompts      <prompt> What are the best practices for rev...
# answers      <ans> Best practices for revenue recognition...
# Name: 271, dtype: object
# prompts      <prompt> How can subscription-based business...
# answers      <ans> Subscription-based businesses can avoi...
# Name: 272, dtype: object
# prompts      <prompt>Outline the key challenges faced by ...
# answers      <ans>1. Infrastructure Evolution Challenge: ...
# Name: 273, dtype: object
# prompts      <prompt> Identify the key areas of expertise...
# answers      <ans> Harikrishna has over seven years of ex...
# Name: 274, dtype: object
# prompts      <prompt> Explain the concept of consumption-...
# answers      <ans> Consumption-based pricing is presented...
# Name: 275, dtype: object
# prompts      <prompt> What are some of the topics covered...
# answers      <ans> The latest product innovations mention...
# Name: 276, dtype: object
# prompts      <prompt> What is the significance of targeti...
# answers      <ans> The text suggests that targeting Latin...
# Name: 277, dtype: object
# prompts      <prompt> What are the top warning signs of f...
# answers      <ans> The text lists "top warning signs" but...
# Name: 278, dtype: object
# prompts      <prompt> What are the five metrics for effic...
# answers      <ans> The text mentions "top five metrics fo...
# Name: 279, dtype: object
# prompts      <prompt> What is the purpose of the Chargebe...
# answers      <ans> The Chargebee, Inc website serves as a...
# Name: 280, dtype: object
# prompts      <prompt> What is the main focus of the Great...
# answers      <ans> The Great Middling: Hybrid Pricing Mod...
# Name: 281, dtype: object
# prompts      <prompt> What are the benefits of having mul...
# answers      <ans> The text suggests that having multiple...
# Name: 282, dtype: object
# prompts      <prompt> What is the purpose of the subscrip...
# answers      <ans> The subscription industry newsletter a...
# Name: 283, dtype: object
# prompts      <prompt> Outline the key responsibilities an...
# answers      <ans> A notable marketing leader in the tech...
# Name: 334, dtype: object
# prompts      <prompt> Identify the various marketing role...
# answers      <ans> Various marketing roles and strategies...
# Name: 335, dtype: object
# prompts      <prompt> Explain the importance of staying u...
# answers      <ans> Staying updated on product innovations...
# Name: 336, dtype: object
# prompts      <prompt> Discuss the role of webinars in a c...
# answers      <ans> Webinars play a significant role in a ...
# Name: 337, dtype: object
# prompts      <prompt> Describe the concept of retention m...
# answers      <ans> Retention management refers to the str...
# Name: 338, dtype: object
# prompts      <prompt> Explain the significance of custome...
# answers      <ans> Customer service and sales tips are cr...
# Name: 339, dtype: object
# prompts      <prompt> Discuss the role of industry best p...
# answers      <ans> Industry best practices play a vital r...
# Name: 340, dtype: object
# prompts      <prompt> Outline the benefits of subscriptio...
# answers      <ans> Subscriptions offer several benefits f...
# Name: 341, dtype: object
# prompts      <prompt> Explain the concept of product decl...
# answers      <ans> Product decluttering refers to the pro...
# Name: 342, dtype: object
# prompts      <prompt> Discuss the importance of churn man...
# answers      <ans> Churn management is essential for the ...
# Name: 343, dtype: object
# prompts      <prompt> Explain the concept of marketing na...
# answers      <ans> Marketing narratives are compelling st...
# Name: 344, dtype: object
# prompts      <prompt> Describe the benefits of outbound g...
# answers      <ans> Outbound growth motions refer to the s...
# Name: 345, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 346, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 347, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 348, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 349, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 350, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 351, dtype: object
# prompts      <prompt>Generate a list of the top subscript...
# answers      <ans>The text does not provide specific info...
# Name: 353, dtype: object
# prompts      <prompt>Describe the key features and benefi...
# answers      <ans>Subscription Ramps is a product innovat...
# Name: 354, dtype: object
# prompts      <prompt>Explain how Chargebee's Full Page Ch...
# answers                  <ans>Chargebee's Full Page Checkout
# Name: 355, dtype: object
# prompts      <prompt> Outline the key strategies employed...
# answers      <ans> Neeraja Subramanian has utilized strat...
# Name: 356, dtype: object
# prompts      <prompt> Discuss the importance of eInvoicin...
# answers      <ans> eInvoicing compliance plays a crucial ...
# Name: 357, dtype: object
# prompts      <prompt> Explain the concept of enhanced Quo...
# answers      <ans> Enhanced Quote-to-Cash efficiency invo...
# Name: 358, dtype: object
# prompts      <prompt> Describe the benefits of declutteri...
# answers      <ans> Decluttering and systemizing a product...
# Name: 359, dtype: object
# prompts      <prompt> Identify the key areas covered in t...
# answers      <ans> The latest product updates cover topic...
# Name: 360, dtype: object
# prompts      <prompt> Discuss the role of Subscription Ra...
# answers      <ans> Subscription Ramps play a significant ...
# Name: 361, dtype: object
# prompts      <prompt> Explain the significance of the Cha...
# answers      <ans> The Chargebee, Inc 2025 update provide...
# Name: 362, dtype: object
# prompts      <prompt> Discuss the impact of strong narrat...
# answers      <ans> Strong narratives can help SaaS busine...
# Name: 363, dtype: object
# prompts      <prompt> Explain the role of GTM strategies ...
# answers      <ans> GTM strategies play a vital role in Sa...
# Name: 364, dtype: object
# prompts      <prompt> Discuss the importance of customer ...
# answers      <ans> Customer service and sales tips are es...
# Name: 365, dtype: object
# prompts      <prompt> Explain the significance of industr...
# answers      <ans> Industry best practices provide SaaS c...
# Name: 366, dtype: object
# prompts      <prompt> Discuss the role of SaaS businesses...
# answers      <ans> SaaS businesses play a crucial role in...
# Name: 367, dtype: object
# prompts      <prompt> Explain the concept of multi-produc...
# answers      <ans> Multi-product launches involve introdu...
# Name: 368, dtype: object
# prompts      <prompt> Discuss the importance of navigatin...
# answers      <ans> Navigating global business expansion i...
# Name: 369, dtype: object
# prompts      <prompt> Explain the concept of monetizing e...
# answers      <ans> Monetizing effectively in SaaS busines...
# Name: 370, dtype: object
# prompts      <prompt> Discuss the role of industry best p...
# answers      <ans> Industry best practices provide SaaS b...
# Name: 371, dtype: object
# prompts      <prompt> Explain the significance of the Cha...
# answers      <ans> The Chargebee, Inc 2025 update provide...
# Name: 372, dtype: object
# prompts      <prompt> Discuss the impact of customer serv...
# answers      <ans> Customer service and sales tips can si...
# Name: 373, dtype: object
# prompts      <prompt> Explain the concept of Revenue Grow...
# answers      <ans> Revenue Growth Management in SaaS busi...
# Name: 374, dtype: object
# prompts      <prompt> Discuss the importance of declutter...
# answers      <ans> Decluttering and systemizing a product...
# Name: 375, dtype: object
# prompts      <prompt> Explain the concept of eInvoicing c...
# answers      <ans> eInvoicing compliance refers to adheri...
# Name: 376, dtype: object
# prompts      <prompt> Discuss the role of GTM strategies ...
# answers            <ans> GTM strategies play a vital role in
# Name: 377, dtype: object
# prompts      <prompt> Outline the key areas of expertise ...
# answers      <ans> A product marketer in the SaaS industr...
# Name: 378, dtype: object
# prompts      <prompt> Describe the process of migrating a...
# answers      <ans> Migrating a large number of records fr...
# Name: 379, dtype: object
# prompts      <prompt> Explain the importance of customer ...
# answers      <ans> Customer retention is crucial for busi...
# Name: 380, dtype: object
# prompts      <prompt> Discuss the challenges faced by sub...
# answers      <ans> Subscription businesses face challenge...
# Name: 381, dtype: object
# prompts      <prompt> Identify the benefits of staying up...
# answers      <ans> Staying updated with the latest produc...
# Name: 382, dtype: object
# prompts      <prompt> Explain the role of a product marke...
# answers      <ans> A product marketer in the SaaS industr...
# Name: 383, dtype: object
# prompts      <prompt> Discuss the significance of a succe...
# answers      <ans> A successful product release in the Sa...
# Name: 384, dtype: object
# prompts      <prompt> Explain the concept of churn manage...
# answers      <ans> Churn management in the SaaS industry ...
# Name: 385, dtype: object
# prompts      <prompt> Discuss the benefits of a seamless ...
# answers      <ans> A seamless billing system migration of...
# Name: 386, dtype: object
# prompts      <prompt> Explain the role of industry best p...
# answers      <ans> Industry best practices in the SaaS in...
# Name: 387, dtype: object
# prompts      <prompt> Outline the key responsibilities an...
# answers      <ans> A Senior Performance Marketing Manager...
# Name: 388, dtype: object
# prompts      <prompt> Identify the major product updates ...
# answers      <ans> In the last year, a SaaS company intro...
# Name: 389, dtype: object
# prompts      <prompt> Explain the importance of understan...
# answers      <ans> Understanding subscriber behavior and ...
# Name: 390, dtype: object
# prompts      <prompt> Describe the role of RevenueStory i...
# answers      <ans> RevenueStory is a valuable resource fo...
# Name: 391, dtype: object
# prompts      <prompt> Discuss the significance of Chargeb...
# answers      <ans> Chargebee's Billing Updates play a sig...
# Name: 392, dtype: object
# prompts      <prompt> Explain the concept of 'The Other S...
# answers      <ans> 'The Other Side of RevOps' refers to t...
# Name: 393, dtype: object
# prompts      <prompt> Discuss the benefits of subscribing...
# answers      <ans> Subscribing to Chargebee's resources p...
# Name: 394, dtype: object
# prompts      <prompt> Explain the concept of 'Moments' in...
# answers      <ans> 'Moments' in Chargebee's marketing str...
# Name: 395, dtype: object
# prompts      <prompt> Discuss the importance of demand ge...
# answers      <ans> Demand generation and campaign strateg...
# Name: 396, dtype: object
# prompts      <prompt> Explain the role of SEO in the SaaS...
# answers      <ans> SEO plays a vital role in the SaaS ind...
# Name: 397, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 398, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 399, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 400, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 401, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 402, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 403, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 404, dtype: object
# prompts      <prompt>Outline the key components of a succ...
# answers      <ans>Successful checkout processes for e-com...
# Name: 405, dtype: object
# prompts      <prompt>Explain the importance of declutteri...
# answers      <ans>Decluttering and systemizing a product ...
# Name: 406, dtype: object
# prompts      <prompt>Discuss the significance of customer...
# answers      <ans>Customer service plays a vital role in ...
# Name: 407, dtype: object
# prompts      <prompt>Describe the potential impact of a "...
# answers      <ans>A "black hole" on an e-commerce checkou...
# Name: 408, dtype: object
# prompts      <prompt>Explain the benefits of subscribing ...
# answers      <ans>Subscribing to a source of information ...
# Name: 409, dtype: object
# prompts      <prompt>Discuss the role of a reliable payme...
# answers      <ans>A reliable payment gateway is essential...
# Name: 410, dtype: object
# prompts      <prompt>Explain the concept of a "moment of ...
# answers      <ans>A "moment of truth" at checkout refers ...
# Name: 411, dtype: object
# prompts      <prompt>Outline the benefits of a subscripti...
# answers      <ans>A subscription-based business model can...
# Name: 412, dtype: object
# prompts      <prompt>Discuss the importance of industry b...
# answers      <ans>Industry best practices provide busines...
# Name: 413, dtype: object
# prompts      <prompt>Explain the concept of a "product ca...
# answers      <ans>A product catalog is a comprehensive li...
# Name: 414, dtype: object
# prompts      <prompt> Identify and describe the key takea...
# answers      <ans> Key takeaways from the provided data i...
# Name: 415, dtype: object
# prompts      <prompt> Explain the significance of the Cha...
# answers      <ans> The Chargebee and Replly integration m...
# Name: 416, dtype: object
# prompts      <prompt> Discuss the concept of churn predic...
# answers      <ans> Churn prediction refers to the process...
# Name: 417, dtype: object
# prompts      <prompt> Describe the impact of the Chargebe...
# answers      <ans> The Chargebee and HubSpot integration ...
# Name: 418, dtype: object
# prompts      <prompt> Explain the concept of the track, a...
# answers      <ans> The track, act, and prevent approach t...
# Name: 419, dtype: object
# prompts      <prompt> Discuss the role of subscription ma...
# answers      <ans> Subscription management plays a crucia...
# Name: 420, dtype: object
# prompts      <prompt> Explain the concept of a seamless c...
# answers      <ans> A seamless checkout experience refers ...
# Name: 421, dtype: object
# prompts      <prompt> Discuss the impact of the Chargebee...
# answers      <ans> The Chargebee and Replly integration h...
# Name: 422, dtype: object
# prompts      <prompt> Explain the concept of post-event s...
# answers      <ans> Post-event subscriber retention in str...
# Name: 423, dtype: object
# prompts      <prompt> Discuss the significance of the Cha...
# answers      <ans> The Chargebee and HubSpot integration ...
# Name: 424, dtype: object
# prompts      <prompt> Explain the concept of a subscripti...
# answers      <ans> A subscription category refers to a sp...
# Name: 425, dtype: object
# prompts      <prompt> Discuss the impact of the Chargebee...
# answers      <ans> The Chargebee and Replly integration h...
# Name: 426, dtype: object
# prompts      <prompt>Generate a list of the top subscript...
# answers      <ans>The text does not provide specific subs...
# Name: 427, dtype: object
# prompts      <prompt>Summarize the key themes discussed i...
# answers      <ans>The webinar highlighted the following k...
# Name: 428, dtype: object
# prompts      <prompt> Outline the key strategies mentione...
# answers      <ans> The key strategies mentioned in the te...
# Name: 429, dtype: object
# prompts      <prompt> Identify the companies mentioned in...
# answers      <ans> The companies mentioned in the text th...
# Name: 430, dtype: object
# prompts      <prompt> Explain the concept of "The Moment ...
# answers      <ans> "The Moment of Cancellation" refers to...
# Name: 431, dtype: object
# prompts      <prompt> Describe the benefits of integratin...
# answers      <ans> The integration of Chargebee with Home...
# Name: 432, dtype: object
# prompts      <prompt> Discuss the importance of understan...
# answers      <ans> Understanding churn prediction is cruc...
# Name: 433, dtype: object
# prompts      <prompt> Explain the concept of "The Art of ...
# answers      <ans> "The Art of Growth in the Year of Effi...
# Name: 434, dtype: object
# prompts      <prompt> Discuss the significance of the "Tr...
# answers      <ans> The "Track, Act, and Prevent Approach"...
# Name: 435, dtype: object
# prompts      <prompt> Explain the concept of "Redefining ...
# answers      <ans> "Redefining Subscriptions: Balancing F...
# Name: 436, dtype: object
# prompts      <prompt> Discuss the benefits of simplifying...
# answers      <ans> Simplifying the cancellation process f...
# Name: 437, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 488, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 489, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 490, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 491, dtype: object
# prompts      <prompt> Identify and describe the key strat...
# answers      <ans> The key strategies mentioned for maxim...
# Name: 492, dtype: object
# prompts      <prompt> List the payment gateways mentioned...
# answers      <ans> The payment gateways mentioned in the ...
# Name: 493, dtype: object
# prompts      <prompt> Explain the concept of open banking...
# answers      <ans> Open banking, as described in the text...
# Name: 494, dtype: object
# prompts      <prompt> What are the six best practices for...
# answers      <ans> The six best practices for accounts re...
# Name: 495, dtype: object
# prompts      <prompt> What are the advantages of using mu...
# answers      <ans> The advantages of using multiple payme...
# Name: 496, dtype: object
# prompts      <prompt> What is the purpose of the "2025 Ch...
# answers      <ans> The "2025 Chargebee, Inc" reference in...
# Name: 497, dtype: object
# prompts      <prompt> What is the main focus of the "Winn...
# answers      <ans> The main focus of the "Winning the Rec...
# Name: 498, dtype: object
# prompts      <prompt> What is the primary goal of the "Ac...
# answers      <ans> The primary goal of the "Ace Customer ...
# Name: 499, dtype: object
# prompts      <prompt> What is the purpose of the "2025 Ch...
# answers      <ans> The purpose of the "2025 Chargebee, In...
# Name: 500, dtype: object
# prompts      <prompt> What is the main objective of the "...
# answers      <ans> The main objective of the "Choosing th...
# Name: 501, dtype: object
# prompts      <prompt> What is the primary focus of the "A...
# answers      <ans> The primary focus of the "A Complete O...
# Name: 502, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 504, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 560, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 616, dtype: object
# prompts      <prompt>Identify the key components involved...
# answers      <ans>The key components involved in the fina...
# Name: 628, dtype: object
# prompts      <prompt>Explain the significance of the grow...
# answers      <ans>The growth rate is significant as it in...
# Name: 629, dtype: object
# prompts      <prompt>Describe the potential impact of a h...
# answers      <ans>A high subscription fee can have a mixe...
# Name: 630, dtype: object
# prompts      <prompt>Outline the process of calculating t...
# answers      <ans>The process of calculating the growth r...
# Name: 631, dtype: object
# prompts      <prompt>Discuss the potential factors that c...
# answers      <ans>Several factors can influence the activ...
# Name: 632, dtype: object
# prompts      <prompt>Explain the relationship between rev...
# answers      <ans>Revenue and active subscribers have a d...
# Name: 633, dtype: object
# prompts          <prompt>
# answers      <ans>  <ans>
# Name: 634, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 635, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 636, dtype: object
# prompts      <prompt>Identify the key components involved...
# answers      <ans>The key components involved in the fina...
# Name: 637, dtype: object
# prompts      <prompt>Explain the significance of the grow...
# answers      <ans>The growth rate is significant as it in...
# Name: 638, dtype: object
# prompts      <prompt>Describe the potential impact of a h...
# answers      <ans>A high subscription fee can have a mixe...
# Name: 639, dtype: object
# prompts      <prompt>Outline the process of calculating t...
# answers      <ans>The process of calculating the growth r...
# Name: 640, dtype: object
# prompts      <prompt>Discuss the potential factors that c...
# answers      <ans>Several factors can influence the activ...
# Name: 641, dtype: object
# prompts      <prompt>Explain the relationship between rev...
# answers      <ans>Revenue and active subscribers have a d...
# Name: 642, dtype: object
# prompts          <prompt>
# answers      <ans>  <ans>
# Name: 643, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 644, dtype: object
# prompts      <prompt>Identify the key components involved...
# answers      <ans>The key components involved in the fina...
# Name: 645, dtype: object
# prompts      <prompt>Explain the significance of the grow...
# answers      <ans>The growth rate is significant as it in...
# Name: 646, dtype: object
# prompts      <prompt>Describe the potential impact of a h...
# answers      <ans>A high subscription fee can have a mixe...
# Name: 647, dtype: object
# prompts      <prompt>Outline the process of calculating t...
# answers      <ans>The process of calculating the growth r...
# Name: 648, dtype: object
# prompts      <prompt>Discuss the potential factors that c...
# answers      <ans>Several factors can influence the activ...
# Name: 649, dtype: object
# prompts      <prompt>Explain the relationship between rev...
# answers      <ans>Revenue and active subscribers have a d...
# Name: 650, dtype: object
# prompts          <prompt>
# answers      <ans>  <ans>
# Name: 651, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 652, dtype: object
# prompts      <prompt>
# answers         <ans>
# Name: 653, dtype: object
# prompts      <prompt> Explain the concept of automated re...
# answers      <ans> Automated recurring payments refer to ...
# Name: 654, dtype: object
# prompts      <prompt> Identify the key features of the Ga...
# answers      <ans> The Gateway Evaluator, as mentioned in...
# Name: 655, dtype: object
# prompts      <prompt> Discuss the potential advantages of...
# answers      <ans> Using a payment gateway offers several...
# Name: 656, dtype: object
# prompts      <prompt> Explain the significance of the lis...
# answers      <ans> The listed countries in the context of...
# Name: 657, dtype: object
# prompts      <prompt> Describe the potential impact of au...
# answers      <ans> Automated recurring payments can have ...
# Name: 658, dtype: object
# prompts      <prompt> Explain the concept of automated re...
# answers      <ans> Automated recurring payments refer to ...
# Name: 659, dtype: object
# prompts      <prompt> Identify the key features of the Ga...
# answers      <ans> The Gateway Evaluator, as mentioned in...
# Name: 660, dtype: object
# prompts      <prompt> Discuss the potential advantages of...
# answers      <ans> Using a payment gateway offers several...
# Name: 661, dtype: object
# prompts      <prompt> Explain the significance of the lis...
# answers      <ans> The listed countries in the context of...
# Name: 662, dtype: object
# prompts      <prompt> Describe the potential impact of au...
# answers      <ans> Automated recurring payments can have ...
# Name: 663, dtype: object
# prompts      <prompt>What are the key considerations for ...
# answers      <ans>The key considerations for a SaaS compa...
# Name: 664, dtype: object
# prompts      <prompt>What are the benefits of experimenti...
# answers      <ans>The benefits of experimenting with pric...
# Name: 665, dtype: object
# prompts      <prompt>What are the two pricing models ment...
# answers      <ans>The two pricing models mentioned in the...
# Name: 666, dtype: object
# prompts      <prompt>What are the potential drawbacks of ...
# answers      <ans>The potential drawbacks of a linear sca...
# Name: 667, dtype: object
# prompts      <prompt>How can a SaaS company determine the...
# answers      <ans>A SaaS company can determine the right ...
# Name: 668, dtype: object
# prompts      <prompt> Explain the concept of automated re...
# answers      <ans> Automated recurring payments refer to ...
# Name: 669, dtype: object
# prompts      <prompt> Identify the key features of the Ga...
# answers      <ans> The Gateway Evaluator, as mentioned in...
# Name: 670, dtype: object
# prompts      <prompt> Discuss the potential advantages of...
# answers      <ans> Using a payment gateway offers several...
# Name: 671, dtype: object
# prompts      <prompt> Explain the significance of the lis...
# answers      <ans> The listed countries in the context of...
# Name: 672, dtype: object
# prompts      <prompt> Describe the potential impact of au...
# answers      <ans> Automated recurring payments can have ...
# Name: 673, dtype: object
# prompts      <prompt> Identify the key areas of expertise...
# answers      <ans> The key areas of expertise for the ind...
# Name: 674, dtype: object
# prompts      <prompt> Describe the professional backgroun...
# answers      <ans> The individual mentioned in the text h...
# Name: 675, dtype: object
# prompts      <prompt> What are some of the best practices...
# answers      <ans> Some of the best practices mentioned i...
# Name: 676, dtype: object
# prompts      <prompt> What is the purpose of the "Release...
# answers      <ans> The purpose of the "Release Roundup" m...
# Name: 677, dtype: object
# prompts      <prompt> What is the significance of the "Pr...
# answers      <ans> The "Product Updates" mentioned in the...
# Name: 678, dtype: object
# prompts      <prompt> What is the role of the individual ...
# answers      <ans> In the "Migrating 12 Million Records f...
# Name: 679, dtype: object
# prompts      <prompt>Describe the financial benefits that...
# answers      <ans>By integrating Chargebee and Pipe into ...
# Name: 680, dtype: object
# prompts      <prompt>Explain how the integration of Charg...
# answers      <ans>The integration of Chargebee and Pipe p...
# Name: 681, dtype: object
# prompts      <prompt>Discuss the impact of the subscripti...
# answers      <ans>The subscription-based business model h...
# Name: 682, dtype: object
# prompts      <prompt>Generate a list of key features that...
# answers      <ans>1. Trigger-based Emails: Emails sent ou...
# Name: 683, dtype: object
# prompts      <prompt> Identify the key strategies mention...
# answers      <ans> The key strategies mentioned in the te...
# Name: 684, dtype: object
# prompts      <prompt> Explain the importance of product u...
# answers      <ans> Product updates and subscriptions play...
# Name: 685, dtype: object
# prompts      <prompt> Discuss the significance of multi-c...
# answers      <ans> Multi-currency and multi-lingual suppo...
# Name: 686, dtype: object
# prompts      <prompt> What are the benefits of implementi...
# answers      <ans> Implementing ASC 606, as mentioned in ...
# Name: 687, dtype: object
# prompts      <prompt> How can businesses leverage free tr...
# answers      <ans> Businesses can leverage free trials as...
# Name: 688, dtype: object
# prompts      <prompt>Outline the key considerations and s...
# answers      <ans>1. Incorporating in the USA as a Delawa...
# Name: 689, dtype: object
# prompts      <prompt>Identify the key components involved...
# answers      <ans>The key components involved in the fina...
# Name: 690, dtype: object
# prompts      <prompt>Explain the significance of the grow...
# answers      <ans>The growth rate is significant as it in...
# Name: 691, dtype: object
# prompts      <prompt>Describe the potential impact of a h...
# answers      <ans>A high subscription fee can have a mixe...
# Name: 692, dtype: object
# prompts      <prompt>Outline the process of calculating t...
# answers      <ans>The process of calculating the growth r...
# Name: 693, dtype: object
# prompts      <prompt>Discuss the potential factors that c...
# answers      <ans>Several factors can influence the activ...
# Name: 694, dtype: object
# prompts      <prompt>Explain the relationship between rev...
# answers      <ans>Revenue and active subscribers have a d...
# Name: 695, dtype: object
# prompts      <prompt> Identify the key factors that contr...
# answers      <ans> The key factors contributing to the su...
# Name: 696, dtype: object
# prompts      <prompt> Discuss the importance of diversity...
# answers      <ans> Diversity and self-reinvention play a ...
# Name: 697, dtype: object
# prompts      <prompt> Explain the significance of buildin...
# answers      <ans> Building a local team is a crucial asp...
# Name: 698, dtype: object
# prompts      <prompt> Describe the growth trajectory of F...
# answers      <ans> Freshdesk has experienced significant ...
# Name: 699, dtype: object
# prompts      <prompt> Discuss the challenges involved in ...
# answers      <ans> Expanding a SaaS product to a new mark...
# Name: 700, dtype: object
# prompts      <prompt> Explain the importance of declutter...
# answers      <ans> Decluttering and systemizing a product...
# Name: 701, dtype: object
# prompts      <prompt> What are some benefits of subscribi...
# answers      <ans> Subscribing to industry best practices...
# Name: 702, dtype: object
# prompts      <prompt> How can data-driven pricing decisio...
# answers      <ans> Data-driven pricing decisions can have...
# Name: 703, dtype: object
# prompts      <prompt> What are some key factors to consid...
# answers      <ans> When creating a subscription model, bu...
# Name: 704, dtype: object
# prompts      <prompt> How can a subscription service help...
# answers      <ans> A subscription service can help a busi...
# Name: 705, dtype: object
# prompts      <prompt>Generate a list of the key component...
# answers      <ans>The key components of the FTC's Negativ...
# Name: 706, dtype: object
# prompts      <prompt>Explain how Chargebee Retention can ...
# answers      <ans>Chargebee Retention can assist business...
# Name: 707, dtype: object
# prompts      <prompt>Describe the purpose of the cancel p...
# answers      <ans>The purpose of the cancel page in the c...
# Name: 708, dtype: object
# prompts      <prompt>What is the significance of loss ave...
# answers      <ans>The significance of loss aversion offer...
# Name: 709, dtype: object
# prompts      <prompt>How can businesses balance complianc...
# answers      <ans>Businesses can balance compliance with ...
# Name: 710, dtype: object
# prompts      <prompt>What are the key characteristics of ...
# answers      <ans>The key characteristics of an antifragi...
# Name: 711, dtype: object
# prompts      <prompt>How does an antifragile revenue oper...
# answers      <ans>An antifragile revenue operations workf...
# Name: 712, dtype: object
# prompts      <prompt>Generate a list of key metrics that ...
# answers      <ans>1. Monthly Recurring Revenue (MRR): MRR...
# Name: 713, dtype: object
# prompts      <prompt>Describe the potential impacts of th...
# answers      <ans>The new revenue recognition standard, A...
# Name: 714, dtype: object
# prompts      <prompt>Generate a prompt that asks for an a...
# answers      <ans>Analyze the growth trends in ecommerce ...
# Name: 715, dtype: object
# prompts      <prompt>Create a prompt that requests a comp...
# answers      <ans>Compare the popularity and growth rates...
# Name: 716, dtype: object
# prompts      <prompt>Formulate a prompt that asks for an ...
# answers      <ans>Evaluate the benefits and challenges th...
# Name: 717, dtype: object
# prompts      <prompt>Generate a prompt that requests an e...
# answers      <ans>Explain the significance of personaliza...
# Name: 718, dtype: object
# prompts      <prompt>Create a prompt that asks for an ana...
# answers      <ans>Analyze the impact of the pandemic on t...
# Name: 719, dtype: object
# prompts      <prompt>Formulate a prompt that requests a d...
# answers      <ans>Discuss the potential long-term sustain...
# Name: 720, dtype: object
# prompts      <prompt>Generate a prompt that asks for an e...
# answers      <ans>Explain the benefits of ecommerce subsc...
# Name: 721, dtype: object
# prompts      <prompt>Create a prompt that requests a comp...
# answers      <ans>Compare the unique features and target ...
# Name: 722, dtype: object
# prompts      <prompt>Formulate a prompt that asks for an ...
# answers      <ans>Analyze the role of technology in the g...
# Name: 723, dtype: object
# prompts      <prompt>Describe the relationship between tw...
# answers      <ans>The relationship between Intruder and C...
# Name: 724, dtype: object
# prompts      <prompt>Explain the purpose of a specific pl...
# answers      <ans>The purpose of ChartMogul's Subscriptio...
# Name: 725, dtype: object
# prompts      <prompt>Identify the type of service or plat...
# answers      <ans>The service mentioned in the text is Ch...
# Name: 726, dtype: object
# prompts      <prompt> Explain the key steps involved in c...
# answers      <ans> Creating a successful SaaS audience in...
# Name: 727, dtype: object
# prompts      <prompt> Describe the significance of the B2...
# answers      <ans> The B2B Rocks conference holds signifi...
# Name: 728, dtype: object
# prompts      <prompt> Discuss the role of ChartMogul's Su...
# answers      <ans> ChartMogul's Subscription Analytics Pl...
# Name: 729, dtype: object
# prompts      <prompt> Explain the concept of a starter ch...
# answers      <ans> Starter Churn Insights is a concept th...
# Name: 730, dtype: object
# prompts      <prompt> Discuss the importance of localizat...
# answers      <ans> Localization plays a crucial role in t...
# Name: 731, dtype: object
# prompts      <prompt> Describe the role of subscriptions ...
# answers      <ans> Subscriptions play a significant role ...
# Name: 732, dtype: object
# prompts      <prompt>Describe the challenges faced by the...
# answers      <ans>The finance team in the SaaS business f...
# Name: 733, dtype: object
# prompts      <prompt>Explain how Chargebee's automation a...
# answers      <ans>Chargebee's automation and integrative ...
# Name: 734, dtype: object
# prompts      <prompt> Explain the professional background...
# answers      <ans> The individual mentioned in the text, ...
# Name: 735, dtype: object
# prompts      <prompt> Identify the strategies mentioned i...
# answers      <ans> The text mentions six proven strategie...
# Name: 736, dtype: object
# prompts      <prompt> Describe the benefits of subscribin...
# answers      <ans> Subscribing to the source mentioned in...
# Name: 737, dtype: object
# prompts      <prompt> Explain the concept of SaaS pricing...
# answers      <ans> SaaS pricing models refer to the vario...
# Name: 738, dtype: object

# %%
df
# Out:
#                                                prompts  \
# 0      <prompt> Identify and describe the key facto...
# 1      <prompt> Explain the importance of a seamles...
# 2      <prompt> Discuss the potential risks and cha...
# 3      <prompt> Describe the benefits of using AI-d...
# 4      <prompt> Explain the role of eInvoicing in n...
# ..                                                 ...
# 734    <prompt>Explain how Chargebee's automation a...
# 735    <prompt> Explain the professional background...
# 736    <prompt> Identify the strategies mentioned i...
# 737    <prompt> Describe the benefits of subscribin...
# 738    <prompt> Explain the concept of SaaS pricing...
#
#                                                answers  \
# 0      <ans> Key factors that contribute to success...
# 1      <ans> A seamless checkout experience is cruc...
# 2      <ans> Homegrown billing systems may face cha...
# 3      <ans> AI-driven offers can help subscription...
# 4      <ans> EInvoicing plays a crucial role in nav...
# ..                                                 ...
# 734    <ans>Chargebee's automation and integrative ...
# 735    <ans> The individual mentioned in the text, ...
# 736    <ans> The text mentions six proven strategie...
# 737    <ans> Subscribing to the source mentioned in...
# 738    <ans> SaaS pricing models refer to the vario...
#
#                                              llm_input
# 0    Below is an instruction that describes a task....
# 1    Below is an instruction that describes a task....
# 2    Below is an instruction that describes a task....
# 3    Below is an instruction that describes a task....
# 4    Below is an instruction that describes a task....
# ..                                                 ...
# 734  Below is an instruction that describes a task....
# 735  Below is an instruction that describes a task....
# 736  Below is an instruction that describes a task....
# 737  Below is an instruction that describes a task....
# 738  Below is an instruction that describes a task....
#
# [366 rows x 3 columns]

# %%
train_portion = int(len(df) * 0.85 )
test_portion = int(len(df) * 0.1 )
val_portion = 0.05

# %%
train_data = df.iloc[:train_portion]
test_data = df.iloc[train_portion: train_portion+test_portion]
val_data = df.iloc[train_portion+test_portion:]

# %%
val_data['llm_input'].values[-1]
# Out:
# "Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n ### Instruction:\n Explain the concept of SaaS pricing models and their potential impact on a startup's revenue.\n\n### Response: \n SaaS pricing models refer to the various strategies that companies use to determine the price of their software as a service offerings. These models can significantly impact a startup's revenue by influencing customer acquisition, retention, and overall profitability. Some common SaaS pricing models include subscription-based pricing, freemium models, tiered pricing, and usage-based pricing. Each model has its own advantages and disadvantages, and the choice of model can depend on factors such as the target customer segment, the value proposition of the software, and the competitive landscape. For instance, a subscription-based pricing model can provide a predictable and recurring revenue stream, while a freemium model can help attract a larger user base and potentially convert them into paying customers. Ultimately, the right pricing model can help a startup maximize its revenue potential while ensuring customer satisfaction and long-term growth."

# %%
print("Training set length:", len(train_data))
print("Validation set length:", len(val_data))
print("Test set length:", len(test_data))
# Out:
# Training set length: 311
# Validation set length: 19
# Test set length: 36

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %%
class InstructionDataset(Dataset):
    def __init__(self,data, tokenizer):
        self.data = data,
        self.encoded_texts = []
        for index,entry in data.iterrows():
            full_text = formatData(entry)
            self.encoded_texts.append(tokenizer.encode(full_text))
    def __getitem__(self,index):
        return self.encoded_texts[index]

    def __len__(self):
        return len(self.data)

# %%
import tiktoken
tokenizer = tiktoken.get_encoding("gpt2")
print(tokenizer.encode("<|endoftext|>", allowed_special={"<|endoftext|>"}))
# Out:
# [50256]

# %%
# !pip install tiktoken

# %%
def custom_collate_draft_1( batch, pad_token_id = 50256, device="cpu"):
    batch_max_length = max(len(item)+1 for item in batch)
    inputs_lst = []
    for item in batch:
        new_item = item.copy()
        new_item += [pad_token_id]
        padded = ( new_item + [pad_token_id] * (batch_max_length - len(new_item) ))
        inputs = torch.tensor(padded[:-1])
        inputs_lst.append(inputs)
    inputs_tensor = torch.stack(inputs_lst).to(device)
    return inputs_tensor

# %%
inputs_1 = [0, 1, 2, 3, 4]
inputs_2 = [5, 6]
inputs_3 = [7, 8, 9]
batch = (
inputs_1,
inputs_2,
inputs_3
)
print(custom_collate_draft_1(batch))
# Out:
# tensor([[    0,     1,     2,     3,     4],
#         [    5,     6, 50256, 50256, 50256],
#         [    7,     8,     9, 50256, 50256]])

# %%
def custom_collate_draft_2( batch, pad_token_id = 50256, device="cpu"):
    batch_max_length = max(len(item)+1 for item in batch)
    inputs_lst, targets_lst = [], []
    for item in batch:
        new_item = item.copy()
        new_item += [pad_token_id]
        padded = ( new_item + [pad_token_id] * (batch_max_length - len(new_item) ))
        inputs = torch.tensor(padded[:-1])
        targets = torch.tensor(padded[1:])
        inputs_lst.append(inputs)
        targets_lst.append(targets)
    inputs_tensor = torch.stack(inputs_lst).to(device)
    targets_tensor = torch.stack(targets_lst).to(device)
    return inputs_tensor, targets_tensor

# %%
inputs, targets = custom_collate_draft_2(batch)
print(inputs)
print(targets)
# Out:
# tensor([[    0,     1,     2,     3,     4],
#         [    5,     6, 50256, 50256, 50256],
#         [    7,     8,     9, 50256, 50256]])
# tensor([[    1,     2,     3,     4, 50256],
#         [    6, 50256, 50256, 50256, 50256],
#         [    8,     9, 50256, 50256, 50256]])

# %%
def custom_collate_function( batch, pad_token_id = 50256, ignore_index=-100, allowed_max_length=None, device="cpu"):
    batch_max_length = max(len(item)+1 for item in batch)
    inputs_lst, targets_lst = [], []
    for item in batch:
        new_item = item.copy()
        new_item += [pad_token_id]
        padded = ( new_item + [pad_token_id] * (batch_max_length - len(new_item) ))
        
        inputs = torch.tensor(padded[:-1])
        targets = torch.tensor(padded[1:])

        mask = targets == pad_token_id
        indices = torch.nonzero(mask).squeeze()
    
        if indices.numel() > 1:
            targets[indices[1:]] = ignore_index

        if allowed_max_length is not None:
            inputs = inputs[:allowed_max_length]
            targets = targets[:allowed_max_length]
            
        
        inputs_lst.append(inputs)
        targets_lst.append(targets)
    inputs_tensor = torch.stack(inputs_lst).to(device)
    targets_tensor = torch.stack(targets_lst).to(device)
    return inputs_tensor, targets_tensor

# %%
inputs, targets = custom_collate_function(batch)
print(inputs)
print(targets)
# Out:
# tensor([[    0,     1,     2,     3,     4],
#         [    5,     6, 50256, 50256, 50256],
#         [    7,     8,     9, 50256, 50256]])
# tensor([[    1,     2,     3,     4, 50256],
#         [    6, 50256,  -100,  -100,  -100],
#         [    8,     9, 50256,  -100,  -100]])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
from functools import partial
customized_collate_fn = partial(
    custom_collate_function,
    device=device,
    allowed_max_length=1024
)

# %%
import multiprocessing

# %%
num_workers = 0
batch_size = 8

# %%
torch.manual_seed(123)

# %%
train_dataset = InstructionDataset(train_data, tokenizer)
train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    collate_fn = customized_collate_fn,
    shuffle=True,
    drop_last= True,
    num_workers = num_workers
)
# Out:
# prompts        <prompt> Identify and describe the key facto...
# answers        <ans> Key factors that contribute to success...
# llm_input    Below is an instruction that describes a task....
# Name: 0, dtype: object
# prompts        <prompt> Explain the importance of a seamles...
# answers        <ans> A seamless checkout experience is cruc...
# llm_input    Below is an instruction that describes a task....
# Name: 1, dtype: object
# prompts        <prompt> Discuss the potential risks and cha...
# answers        <ans> Homegrown billing systems may face cha...
# llm_input    Below is an instruction that describes a task....
# Name: 2, dtype: object
# prompts        <prompt> Describe the benefits of using AI-d...
# answers        <ans> AI-driven offers can help subscription...
# llm_input    Below is an instruction that describes a task....
# Name: 3, dtype: object
# prompts        <prompt> Explain the role of eInvoicing in n...
# answers        <ans> EInvoicing plays a crucial role in nav...
# llm_input    Below is an instruction that describes a task....
# Name: 4, dtype: object
# prompts        <prompt> Discuss the impact of subscription ...
# answers        <ans> Subscription growth can significantly ...
# llm_input    Below is an instruction that describes a task....
# Name: 5, dtype: object
# prompts        <prompt> Explain the concept of subscription...
# answers        <ans> Subscription ramps refer to the strate...
# llm_input    Below is an instruction that describes a task....
# Name: 6, dtype: object
# prompts        <prompt> Discuss the best practices for a se...
# answers        <ans> Best practices for a seamless billing ...
# llm_input    Below is an instruction that describes a task....
# Name: 7, dtype: object
# prompts        <prompt> Explain the significance of the Gar...
# answers        <ans> The Gartner Magic Quadrant for Recurri...
# llm_input    Below is an instruction that describes a task....
# Name: 8, dtype: object
# prompts        <prompt> Discuss the potential growth opport...
# answers        <ans> Potential growth opportunities for sub...
# llm_input    Below is an instruction that describes a task....
# Name: 9, dtype: object
# prompts        <prompt> Explain the concept of subscription...
# answers        <ans> Subscription entitlement management re...
# llm_input    Below is an instruction that describes a task....
# Name: 10, dtype: object
# prompts        <prompt> Explain the importance of subscript...
# answers        <ans> The importance of subscriptions for re...
# llm_input    Below is an instruction that describes a task....
# Name: 11, dtype: object
# prompts        <prompt> Discuss the role of personalization...
# answers        <ans> Personalization plays a crucial role i...
# llm_input    Below is an instruction that describes a task....
# Name: 12, dtype: object
# prompts        <prompt> How can businesses leverage cancell...
# answers        <ans> Businesses can leverage cancellation i...
# llm_input    Below is an instruction that describes a task....
# Name: 13, dtype: object
# prompts        <prompt> What strategies can be employed to ...
# answers        <ans> To retain subscribers in the face of i...
# llm_input    Below is an instruction that describes a task....
# Name: 14, dtype: object
# prompts        <prompt> Identify and describe the key facto...
# answers        <ans> Key factors that contribute to success...
# llm_input    Below is an instruction that describes a task....
# Name: 15, dtype: object
# prompts        <prompt> Explain the importance of a seamles...
# answers        <ans> A seamless checkout experience is cruc...
# llm_input    Below is an instruction that describes a task....
# Name: 16, dtype: object
# prompts        <prompt> Discuss the potential risks and cha...
# answers        <ans> Homegrown billing systems may face cha...
# llm_input    Below is an instruction that describes a task....
# Name: 17, dtype: object
# prompts        <prompt> Describe the benefits of using AI-d...
# answers        <ans> AI-driven offers can help subscription...
# llm_input    Below is an instruction that describes a task....
# Name: 18, dtype: object
# prompts        <prompt> Explain the role of eInvoicing in n...
# answers        <ans> EInvoicing plays a crucial role in nav...
# llm_input    Below is an instruction that describes a task....
# Name: 19, dtype: object
# prompts        <prompt> Discuss the impact of subscription ...
# answers        <ans> Subscription growth can significantly ...
# llm_input    Below is an instruction that describes a task....
# Name: 20, dtype: object
# prompts        <prompt> Explain the concept of subscription...
# answers        <ans> Subscription ramps refer to the strate...
# llm_input    Below is an instruction that describes a task....
# Name: 21, dtype: object
# prompts        <prompt> Discuss the best practices for a se...
# answers        <ans> Best practices for a seamless billing ...
# llm_input    Below is an instruction that describes a task....
# Name: 22, dtype: object
# prompts        <prompt> Explain the significance of the Gar...
# answers        <ans> The Gartner Magic Quadrant for Recurri...
# llm_input    Below is an instruction that describes a task....
# Name: 23, dtype: object
# prompts        <prompt> Discuss the potential growth opport...
# answers        <ans> Potential growth opportunities for sub...
# llm_input    Below is an instruction that describes a task....
# Name: 24, dtype: object
# prompts        <prompt> Explain the concept of subscription...
# answers        <ans> Subscription entitlement management re...
# llm_input    Below is an instruction that describes a task....
# Name: 25, dtype: object
# prompts        <prompt> Explain the importance of subscript...
# answers        <ans> The importance of subscriptions for re...
# llm_input    Below is an instruction that describes a task....
# Name: 26, dtype: object
# prompts        <prompt> Discuss the role of personalization...
# answers        <ans> Personalization plays a crucial role i...
# llm_input    Below is an instruction that describes a task....
# Name: 27, dtype: object
# prompts        <prompt> How can businesses leverage cancell...
# answers        <ans> Businesses can leverage cancellation i...
# llm_input    Below is an instruction that describes a task....
# Name: 28, dtype: object
# prompts        <prompt> What strategies can be employed to ...
# answers        <ans> To retain subscribers in the face of i...
# llm_input    Below is an instruction that describes a task....
# Name: 29, dtype: object
# prompts        <prompt> How can businesses effectively comm...
# answers        <ans> Businesses can effectively communicate...
# llm_input    Below is an instruction that describes a task....
# Name: 30, dtype: object
# prompts        <prompt> What are some best practices for bu...
# answers        <ans> To comply with the FTC's Click-to-Canc...
# llm_input    Below is an instruction that describes a task....
# Name: 31, dtype: object
# prompts        <prompt> How can businesses use AI to levera...
# answers        <ans> Businesses can use AI to leverage canc...
# llm_input    Below is an instruction that describes a task....
# Name: 32, dtype: object
# prompts        <prompt> What are some effective strategies ...
# answers        <ans> To foster customer loyalty and retenti...
# llm_input    Below is an instruction that describes a task....
# Name: 33, dtype: object
# prompts        <prompt>Identify the key financial benefits ...
# answers        <ans>The key financial benefits mentioned in...
# llm_input    Below is an instruction that describes a task....
# Name: 84, dtype: object
# prompts        <prompt>Extract the various roles and titles...
# answers        <ans>The various roles and titles mentioned ...
# llm_input    Below is an instruction that describes a task....
# Name: 85, dtype: object
# prompts        <prompt>Identify the different types of inte...
# answers        <ans>The text mentions integrated payment ga...
# llm_input    Below is an instruction that describes a task....
# Name: 86, dtype: object
# prompts        <prompt>Extract the geographical scope of Ch...
# answers        <ans>Chargebee serves customers in 6,500 mer...
# llm_input    Below is an instruction that describes a task....
# Name: 87, dtype: object
# prompts        <prompt>Identify the specific features and c...
# answers        <ans>The text highlights features and capabi...
# llm_input    Below is an instruction that describes a task....
# Name: 88, dtype: object
# prompts        <prompt>Extract the various benefits and out...
# answers        <ans>Companies using Chargebee have experien...
# llm_input    Below is an instruction that describes a task....
# Name: 89, dtype: object
# prompts        <prompt>Identify the different types of even...
# answers        <ans>The text mentions events and resources ...
# llm_input    Below is an instruction that describes a task....
# Name: 90, dtype: object
# prompts        <prompt>Extract the various aspects of Charg...
# answers        <ans>Chargebee's product offerings include a...
# llm_input    Below is an instruction that describes a task....
# Name: 91, dtype: object
# prompts        <prompt>Identify the different types of cust...
# answers        <ans>The text mentions resources such as the...
# llm_input    Below is an instruction that describes a task....
# Name: 92, dtype: object
# prompts        <prompt>Extract the various types of integra...
# answers        <ans>The text mentions integrated payment ga...
# llm_input    Below is an instruction that describes a task....
# Name: 93, dtype: object
# prompts        <prompt>Identify the different types of fina...
# answers        <ans>The text mentions financial metrics and...
# llm_input    Below is an instruction that describes a task....
# Name: 94, dtype: object
# prompts        <prompt>Extract the various types of custome...
# answers        <ans>The text mentions features and capabili...
# llm_input    Below is an instruction that describes a task....
# Name: 95, dtype: object
# prompts        <prompt>Identify the different types of even...
# answers        <ans>The text mentions events and resources ...
# llm_input    Below is an instruction that describes a task....
# Name: 96, dtype: object
# prompts        <prompt>Extract the various types of financi...
# answers        <ans>The text mentions financial benefits an...
# llm_input    Below is an instruction that describes a task....
# Name: 97, dtype: object
# prompts        <prompt> Identify and describe the key facto...
# answers        <ans> Key factors that contribute to success...
# llm_input    Below is an instruction that describes a task....
# Name: 98, dtype: object
# prompts        <prompt> Explain the importance of a seamles...
# answers        <ans> A seamless checkout experience is cruc...
# llm_input    Below is an instruction that describes a task....
# Name: 99, dtype: object
# prompts        <prompt> Discuss the potential risks and cha...
# answers        <ans> Homegrown billing systems may face cha...
# llm_input    Below is an instruction that describes a task....
# Name: 100, dtype: object
# prompts        <prompt> Describe the benefits of using AI-d...
# answers        <ans> AI-driven offers can help subscription...
# llm_input    Below is an instruction that describes a task....
# Name: 101, dtype: object
# prompts        <prompt> Explain the role of eInvoicing in n...
# answers        <ans> EInvoicing plays a crucial role in nav...
# llm_input    Below is an instruction that describes a task....
# Name: 102, dtype: object
# prompts        <prompt> Discuss the impact of subscription ...
# answers        <ans> Subscription growth can significantly ...
# llm_input    Below is an instruction that describes a task....
# Name: 103, dtype: object
# prompts        <prompt> Explain the concept of subscription...
# answers        <ans> Subscription ramps refer to the strate...
# llm_input    Below is an instruction that describes a task....
# Name: 104, dtype: object
# prompts        <prompt> Discuss the best practices for a se...
# answers        <ans> Best practices for a seamless billing ...
# llm_input    Below is an instruction that describes a task....
# Name: 105, dtype: object
# prompts        <prompt> Explain the significance of the Gar...
# answers        <ans> The Gartner Magic Quadrant for Recurri...
# llm_input    Below is an instruction that describes a task....
# Name: 106, dtype: object
# prompts        <prompt> Discuss the potential growth opport...
# answers        <ans> Potential growth opportunities for sub...
# llm_input    Below is an instruction that describes a task....
# Name: 107, dtype: object
# prompts        <prompt> Explain the concept of subscription...
# answers        <ans> Subscription entitlement management re...
# llm_input    Below is an instruction that describes a task....
# Name: 108, dtype: object
# prompts        <prompt> Explain the importance of subscript...
# answers        <ans> The importance of subscriptions for re...
# llm_input    Below is an instruction that describes a task....
# Name: 109, dtype: object
# prompts        <prompt> Discuss the role of personalization...
# answers        <ans> Personalization plays a crucial role i...
# llm_input    Below is an instruction that describes a task....
# Name: 110, dtype: object
# prompts        <prompt> How can businesses leverage cancell...
# answers        <ans> Businesses can leverage cancellation i...
# llm_input    Below is an instruction that describes a task....
# Name: 111, dtype: object
# prompts        <prompt> What strategies can be employed to ...
# answers        <ans> To retain subscribers in the face of i...
# llm_input    Below is an instruction that describes a task....
# Name: 112, dtype: object
# prompts        <prompt> How can businesses effectively comm...
# answers        <ans> Businesses can effectively communicate...
# llm_input    Below is an instruction that describes a task....
# Name: 113, dtype: object
# prompts        <prompt> What are some best practices for bu...
# answers        <ans> To comply with the FTC's Click-to-Canc...
# llm_input    Below is an instruction that describes a task....
# Name: 114, dtype: object
# prompts        <prompt> How can businesses use AI to levera...
# answers        <ans> Businesses can use AI to leverage canc...
# llm_input    Below is an instruction that describes a task....
# Name: 115, dtype: object
# prompts        <prompt> What are some effective strategies ...
# answers        <ans> To foster customer loyalty and retenti...
# llm_input    Below is an instruction that describes a task....
# Name: 116, dtype: object
# prompts        <prompt>Identify the key financial benefits ...
# answers        <ans>The key financial benefits mentioned in...
# llm_input    Below is an instruction that describes a task....
# Name: 167, dtype: object
# prompts        <prompt>Extract the various roles and titles...
# answers        <ans>The various roles and titles mentioned ...
# llm_input    Below is an instruction that describes a task....
# Name: 168, dtype: object
# prompts        <prompt>Identify the different types of inte...
# answers        <ans>The text mentions integrated payment ga...
# llm_input    Below is an instruction that describes a task....
# Name: 169, dtype: object
# prompts        <prompt>Extract the geographical scope of Ch...
# answers        <ans>Chargebee serves customers in 6,500 mer...
# llm_input    Below is an instruction that describes a task....
# Name: 170, dtype: object
# prompts        <prompt>Identify the specific features and c...
# answers        <ans>The text highlights features and capabi...
# llm_input    Below is an instruction that describes a task....
# Name: 171, dtype: object
# prompts        <prompt>Extract the various benefits and out...
# answers        <ans>Companies using Chargebee have experien...
# llm_input    Below is an instruction that describes a task....
# Name: 172, dtype: object
# prompts        <prompt>Identify the different types of even...
# answers        <ans>The text mentions events and resources ...
# llm_input    Below is an instruction that describes a task....
# Name: 173, dtype: object
# prompts        <prompt>Extract the various aspects of Charg...
# answers        <ans>Chargebee's product offerings include a...
# llm_input    Below is an instruction that describes a task....
# Name: 174, dtype: object
# prompts        <prompt>Identify the different types of cust...
# answers        <ans>The text mentions resources such as the...
# llm_input    Below is an instruction that describes a task....
# Name: 175, dtype: object
# prompts        <prompt>Extract the various types of integra...
# answers        <ans>The text mentions integrated payment ga...
# llm_input    Below is an instruction that describes a task....
# Name: 176, dtype: object
# prompts        <prompt>Identify the different types of fina...
# answers        <ans>The text mentions financial metrics and...
# llm_input    Below is an instruction that describes a task....
# Name: 177, dtype: object
# prompts        <prompt>Extract the various types of custome...
# answers        <ans>The text mentions features and capabili...
# llm_input    Below is an instruction that describes a task....
# Name: 178, dtype: object
# prompts        <prompt>Identify the different types of even...
# answers        <ans>The text mentions events and resources ...
# llm_input    Below is an instruction that describes a task....
# Name: 179, dtype: object
# prompts        <prompt>Extract the various types of financi...
# answers        <ans>The text mentions financial benefits an...
# llm_input    Below is an instruction that describes a task....
# Name: 180, dtype: object
# prompts        <prompt> Identify and describe the key facto...
# answers        <ans> Key factors that contribute to success...
# llm_input    Below is an instruction that describes a task....
# Name: 181, dtype: object
# prompts        <prompt> Explain the importance of a seamles...
# answers        <ans> A seamless checkout experience is cruc...
# llm_input    Below is an instruction that describes a task....
# Name: 182, dtype: object
# prompts        <prompt> Discuss the potential risks and cha...
# answers        <ans> Homegrown billing systems may face cha...
# llm_input    Below is an instruction that describes a task....
# Name: 183, dtype: object
# prompts        <prompt> Describe the benefits of using AI-d...
# answers        <ans> AI-driven offers can help subscription...
# llm_input    Below is an instruction that describes a task....
# Name: 184, dtype: object
# prompts        <prompt> Explain the role of eInvoicing in n...
# answers        <ans> EInvoicing plays a crucial role in nav...
# llm_input    Below is an instruction that describes a task....
# Name: 185, dtype: object
# prompts        <prompt> Discuss the impact of subscription ...
# answers        <ans> Subscription growth can significantly ...
# llm_input    Below is an instruction that describes a task....
# Name: 186, dtype: object
# prompts        <prompt> Explain the concept of subscription...
# answers        <ans> Subscription ramps refer to the strate...
# llm_input    Below is an instruction that describes a task....
# Name: 187, dtype: object
# prompts        <prompt> Discuss the best practices for a se...
# answers        <ans> Best practices for a seamless billing ...
# llm_input    Below is an instruction that describes a task....
# Name: 188, dtype: object
# prompts        <prompt> Explain the significance of the Gar...
# answers        <ans> The Gartner Magic Quadrant for Recurri...
# llm_input    Below is an instruction that describes a task....
# Name: 189, dtype: object
# prompts        <prompt> Discuss the potential growth opport...
# answers        <ans> Potential growth opportunities for sub...
# llm_input    Below is an instruction that describes a task....
# Name: 190, dtype: object
# prompts        <prompt> Explain the concept of subscription...
# answers        <ans> Subscription entitlement management re...
# llm_input    Below is an instruction that describes a task....
# Name: 191, dtype: object
# prompts        <prompt> Explain the importance of subscript...
# answers        <ans> The importance of subscriptions for re...
# llm_input    Below is an instruction that describes a task....
# Name: 192, dtype: object
# prompts        <prompt> Discuss the role of personalization...
# answers        <ans> Personalization plays a crucial role i...
# llm_input    Below is an instruction that describes a task....
# Name: 193, dtype: object
# prompts        <prompt> How can businesses leverage cancell...
# answers        <ans> Businesses can leverage cancellation i...
# llm_input    Below is an instruction that describes a task....
# Name: 194, dtype: object
# prompts        <prompt> What strategies can be employed to ...
# answers        <ans> To retain subscribers in the face of i...
# llm_input    Below is an instruction that describes a task....
# Name: 195, dtype: object
# prompts        <prompt> How can businesses effectively comm...
# answers        <ans> Businesses can effectively communicate...
# llm_input    Below is an instruction that describes a task....
# Name: 196, dtype: object
# prompts        <prompt> What are some best practices for bu...
# answers        <ans> To comply with the FTC's Click-to-Canc...
# llm_input    Below is an instruction that describes a task....
# Name: 197, dtype: object
# prompts        <prompt> How can businesses use AI to levera...
# answers        <ans> Businesses can use AI to leverage canc...
# llm_input    Below is an instruction that describes a task....
# Name: 198, dtype: object
# prompts        <prompt> What are some effective strategies ...
# answers        <ans> To foster customer loyalty and retenti...
# llm_input    Below is an instruction that describes a task....
# Name: 199, dtype: object
# prompts        <prompt> Outline the key skills and expertis...
# answers        <ans> A professional in the field of event s...
# llm_input    Below is an instruction that describes a task....
# Name: 250, dtype: object
# prompts        <prompt> Explain the concept of customer lif...
# answers        <ans> Customer lifetime value refers to the ...
# llm_input    Below is an instruction that describes a task....
# Name: 251, dtype: object
# prompts        <prompt> Describe the importance of personal...
# answers        <ans> Personalization in subscription models...
# llm_input    Below is an instruction that describes a task....
# Name: 252, dtype: object
# prompts        <prompt> Discuss the role of event strategy ...
# answers        <ans> Event strategy plays a vital role in d...
# llm_input    Below is an instruction that describes a task....
# Name: 253, dtype: object
# prompts        <prompt> Explain the concept of 'subscriptio...
# answers        <ans> Subscription alchemy refers to the pro...
# llm_input    Below is an instruction that describes a task....
# Name: 254, dtype: object
# prompts        <prompt> Discuss the impact of localization ...
# answers        <ans> Localization plays a crucial role in i...
# llm_input    Below is an instruction that describes a task....
# Name: 255, dtype: object
# prompts        <prompt> Explain the significance of strateg...
# answers        <ans> Strategic partnerships play a signific...
# llm_input    Below is an instruction that describes a task....
# Name: 256, dtype: object
# prompts        <prompt> Discuss the importance of optimizin...
# answers        <ans> Optimizing ticket sales is crucial in ...
# llm_input    Below is an instruction that describes a task....
# Name: 257, dtype: object
# prompts        <prompt> Explain the impact of the psycholog...
# answers        <ans> The psychology of subscriptions plays ...
# llm_input    Below is an instruction that describes a task....
# Name: 258, dtype: object
# prompts        <prompt> Discuss the impact of self-serve ca...
# answers        <ans> Self-serve cancellations can have a si...
# llm_input    Below is an instruction that describes a task....
# Name: 259, dtype: object
# prompts        <prompt> Explain the concept of 'event strat...
# answers        <ans> Event strategy refers to the planning ...
# llm_input    Below is an instruction that describes a task....
# Name: 260, dtype: object
# prompts        <prompt> Discuss the impact of the subscript...
# answers        <ans> The subscription revenue impact of cus...
# llm_input    Below is an instruction that describes a task....
# Name: 261, dtype: object
# prompts        <prompt> Explain the concept of 'subscriptio...
# answers        <ans> Subscription alchemy refers to the pro...
# llm_input    Below is an instruction that describes a task....
# Name: 262, dtype: object
# prompts        <prompt> Identify and describe the key facto...
# answers        <ans> Key factors contributing to the succes...
# llm_input    Below is an instruction that describes a task....
# Name: 263, dtype: object
# prompts        <prompt> Explain the importance of integrati...
# answers        <ans> Integrating payment gateways with subs...
# llm_input    Below is an instruction that describes a task....
# Name: 264, dtype: object
# prompts        <prompt> Discuss the potential risks associa...
# answers        <ans> Homegrown billing systems can pose hid...
# llm_input    Below is an instruction that describes a task....
# Name: 265, dtype: object
# prompts        <prompt> How can subscription management imp...
# answers        <ans> Subscription management can boost a sa...
# llm_input    Below is an instruction that describes a task....
# Name: 266, dtype: object
# prompts        <prompt> What are the benefits of a seamless...
# answers        <ans> A seamless billing system migration ca...
# llm_input    Below is an instruction that describes a task....
# Name: 267, dtype: object
# prompts        <prompt> How can subscription ramps be used ...
# answers        <ans> Subscription ramps can be used to driv...
# llm_input    Below is an instruction that describes a task....
# Name: 268, dtype: object
# prompts        <prompt> What are the key components of a co...
# answers        <ans> Key components of a compliant billing ...
# llm_input    Below is an instruction that describes a task....
# Name: 269, dtype: object
# prompts        <prompt> How can subscription-based business...
# answers        <ans> Subscription-based businesses can leve...
# llm_input    Below is an instruction that describes a task....
# Name: 270, dtype: object
# prompts        <prompt> What are the best practices for rev...
# answers        <ans> Best practices for revenue recognition...
# llm_input    Below is an instruction that describes a task....
# Name: 271, dtype: object
# prompts        <prompt> How can subscription-based business...
# answers        <ans> Subscription-based businesses can avoi...
# llm_input    Below is an instruction that describes a task....
# Name: 272, dtype: object
# prompts        <prompt>Outline the key challenges faced by ...
# answers        <ans>1. Infrastructure Evolution Challenge: ...
# llm_input    Below is an instruction that describes a task....
# Name: 273, dtype: object
# prompts        <prompt> Identify the key areas of expertise...
# answers        <ans> Harikrishna has over seven years of ex...
# llm_input    Below is an instruction that describes a task....
# Name: 274, dtype: object
# prompts        <prompt> Explain the concept of consumption-...
# answers        <ans> Consumption-based pricing is presented...
# llm_input    Below is an instruction that describes a task....
# Name: 275, dtype: object
# prompts        <prompt> What are some of the topics covered...
# answers        <ans> The latest product innovations mention...
# llm_input    Below is an instruction that describes a task....
# Name: 276, dtype: object
# prompts        <prompt> What is the significance of targeti...
# answers        <ans> The text suggests that targeting Latin...
# llm_input    Below is an instruction that describes a task....
# Name: 277, dtype: object
# prompts        <prompt> What are the top warning signs of f...
# answers        <ans> The text lists "top warning signs" but...
# llm_input    Below is an instruction that describes a task....
# Name: 278, dtype: object
# prompts        <prompt> What are the five metrics for effic...
# answers        <ans> The text mentions "top five metrics fo...
# llm_input    Below is an instruction that describes a task....
# Name: 279, dtype: object
# prompts        <prompt> What is the purpose of the Chargebe...
# answers        <ans> The Chargebee, Inc website serves as a...
# llm_input    Below is an instruction that describes a task....
# Name: 280, dtype: object
# prompts        <prompt> What is the main focus of the Great...
# answers        <ans> The Great Middling: Hybrid Pricing Mod...
# llm_input    Below is an instruction that describes a task....
# Name: 281, dtype: object
# prompts        <prompt> What are the benefits of having mul...
# answers        <ans> The text suggests that having multiple...
# llm_input    Below is an instruction that describes a task....
# Name: 282, dtype: object
# prompts        <prompt> What is the purpose of the subscrip...
# answers        <ans> The subscription industry newsletter a...
# llm_input    Below is an instruction that describes a task....
# Name: 283, dtype: object
# prompts        <prompt> Outline the key responsibilities an...
# answers        <ans> A notable marketing leader in the tech...
# llm_input    Below is an instruction that describes a task....
# Name: 334, dtype: object
# prompts        <prompt> Identify the various marketing role...
# answers        <ans> Various marketing roles and strategies...
# llm_input    Below is an instruction that describes a task....
# Name: 335, dtype: object
# prompts        <prompt> Explain the importance of staying u...
# answers        <ans> Staying updated on product innovations...
# llm_input    Below is an instruction that describes a task....
# Name: 336, dtype: object
# prompts        <prompt> Discuss the role of webinars in a c...
# answers        <ans> Webinars play a significant role in a ...
# llm_input    Below is an instruction that describes a task....
# Name: 337, dtype: object
# prompts        <prompt> Describe the concept of retention m...
# answers        <ans> Retention management refers to the str...
# llm_input    Below is an instruction that describes a task....
# Name: 338, dtype: object
# prompts        <prompt> Explain the significance of custome...
# answers        <ans> Customer service and sales tips are cr...
# llm_input    Below is an instruction that describes a task....
# Name: 339, dtype: object
# prompts        <prompt> Discuss the role of industry best p...
# answers        <ans> Industry best practices play a vital r...
# llm_input    Below is an instruction that describes a task....
# Name: 340, dtype: object
# prompts        <prompt> Outline the benefits of subscriptio...
# answers        <ans> Subscriptions offer several benefits f...
# llm_input    Below is an instruction that describes a task....
# Name: 341, dtype: object
# prompts        <prompt> Explain the concept of product decl...
# answers        <ans> Product decluttering refers to the pro...
# llm_input    Below is an instruction that describes a task....
# Name: 342, dtype: object
# prompts        <prompt> Discuss the importance of churn man...
# answers        <ans> Churn management is essential for the ...
# llm_input    Below is an instruction that describes a task....
# Name: 343, dtype: object
# prompts        <prompt> Explain the concept of marketing na...
# answers        <ans> Marketing narratives are compelling st...
# llm_input    Below is an instruction that describes a task....
# Name: 344, dtype: object
# prompts        <prompt> Describe the benefits of outbound g...
# answers        <ans> Outbound growth motions refer to the s...
# llm_input    Below is an instruction that describes a task....
# Name: 345, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 346, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 347, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 348, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 349, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 350, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 351, dtype: object
# prompts        <prompt>Generate a list of the top subscript...
# answers        <ans>The text does not provide specific info...
# llm_input    Below is an instruction that describes a task....
# Name: 353, dtype: object
# prompts        <prompt>Describe the key features and benefi...
# answers        <ans>Subscription Ramps is a product innovat...
# llm_input    Below is an instruction that describes a task....
# Name: 354, dtype: object
# prompts        <prompt>Explain how Chargebee's Full Page Ch...
# answers                    <ans>Chargebee's Full Page Checkout
# llm_input    Below is an instruction that describes a task....
# Name: 355, dtype: object
# prompts        <prompt> Outline the key strategies employed...
# answers        <ans> Neeraja Subramanian has utilized strat...
# llm_input    Below is an instruction that describes a task....
# Name: 356, dtype: object
# prompts        <prompt> Discuss the importance of eInvoicin...
# answers        <ans> eInvoicing compliance plays a crucial ...
# llm_input    Below is an instruction that describes a task....
# Name: 357, dtype: object
# prompts        <prompt> Explain the concept of enhanced Quo...
# answers        <ans> Enhanced Quote-to-Cash efficiency invo...
# llm_input    Below is an instruction that describes a task....
# Name: 358, dtype: object
# prompts        <prompt> Describe the benefits of declutteri...
# answers        <ans> Decluttering and systemizing a product...
# llm_input    Below is an instruction that describes a task....
# Name: 359, dtype: object
# prompts        <prompt> Identify the key areas covered in t...
# answers        <ans> The latest product updates cover topic...
# llm_input    Below is an instruction that describes a task....
# Name: 360, dtype: object
# prompts        <prompt> Discuss the role of Subscription Ra...
# answers        <ans> Subscription Ramps play a significant ...
# llm_input    Below is an instruction that describes a task....
# Name: 361, dtype: object
# prompts        <prompt> Explain the significance of the Cha...
# answers        <ans> The Chargebee, Inc 2025 update provide...
# llm_input    Below is an instruction that describes a task....
# Name: 362, dtype: object
# prompts        <prompt> Discuss the impact of strong narrat...
# answers        <ans> Strong narratives can help SaaS busine...
# llm_input    Below is an instruction that describes a task....
# Name: 363, dtype: object
# prompts        <prompt> Explain the role of GTM strategies ...
# answers        <ans> GTM strategies play a vital role in Sa...
# llm_input    Below is an instruction that describes a task....
# Name: 364, dtype: object
# prompts        <prompt> Discuss the importance of customer ...
# answers        <ans> Customer service and sales tips are es...
# llm_input    Below is an instruction that describes a task....
# Name: 365, dtype: object
# prompts        <prompt> Explain the significance of industr...
# answers        <ans> Industry best practices provide SaaS c...
# llm_input    Below is an instruction that describes a task....
# Name: 366, dtype: object
# prompts        <prompt> Discuss the role of SaaS businesses...
# answers        <ans> SaaS businesses play a crucial role in...
# llm_input    Below is an instruction that describes a task....
# Name: 367, dtype: object
# prompts        <prompt> Explain the concept of multi-produc...
# answers        <ans> Multi-product launches involve introdu...
# llm_input    Below is an instruction that describes a task....
# Name: 368, dtype: object
# prompts        <prompt> Discuss the importance of navigatin...
# answers        <ans> Navigating global business expansion i...
# llm_input    Below is an instruction that describes a task....
# Name: 369, dtype: object
# prompts        <prompt> Explain the concept of monetizing e...
# answers        <ans> Monetizing effectively in SaaS busines...
# llm_input    Below is an instruction that describes a task....
# Name: 370, dtype: object
# prompts        <prompt> Discuss the role of industry best p...
# answers        <ans> Industry best practices provide SaaS b...
# llm_input    Below is an instruction that describes a task....
# Name: 371, dtype: object
# prompts        <prompt> Explain the significance of the Cha...
# answers        <ans> The Chargebee, Inc 2025 update provide...
# llm_input    Below is an instruction that describes a task....
# Name: 372, dtype: object
# prompts        <prompt> Discuss the impact of customer serv...
# answers        <ans> Customer service and sales tips can si...
# llm_input    Below is an instruction that describes a task....
# Name: 373, dtype: object
# prompts        <prompt> Explain the concept of Revenue Grow...
# answers        <ans> Revenue Growth Management in SaaS busi...
# llm_input    Below is an instruction that describes a task....
# Name: 374, dtype: object
# prompts        <prompt> Discuss the importance of declutter...
# answers        <ans> Decluttering and systemizing a product...
# llm_input    Below is an instruction that describes a task....
# Name: 375, dtype: object
# prompts        <prompt> Explain the concept of eInvoicing c...
# answers        <ans> eInvoicing compliance refers to adheri...
# llm_input    Below is an instruction that describes a task....
# Name: 376, dtype: object
# prompts        <prompt> Discuss the role of GTM strategies ...
# answers              <ans> GTM strategies play a vital role in
# llm_input    Below is an instruction that describes a task....
# Name: 377, dtype: object
# prompts        <prompt> Outline the key areas of expertise ...
# answers        <ans> A product marketer in the SaaS industr...
# llm_input    Below is an instruction that describes a task....
# Name: 378, dtype: object
# prompts        <prompt> Describe the process of migrating a...
# answers        <ans> Migrating a large number of records fr...
# llm_input    Below is an instruction that describes a task....
# Name: 379, dtype: object
# prompts        <prompt> Explain the importance of customer ...
# answers        <ans> Customer retention is crucial for busi...
# llm_input    Below is an instruction that describes a task....
# Name: 380, dtype: object
# prompts        <prompt> Discuss the challenges faced by sub...
# answers        <ans> Subscription businesses face challenge...
# llm_input    Below is an instruction that describes a task....
# Name: 381, dtype: object
# prompts        <prompt> Identify the benefits of staying up...
# answers        <ans> Staying updated with the latest produc...
# llm_input    Below is an instruction that describes a task....
# Name: 382, dtype: object
# prompts        <prompt> Explain the role of a product marke...
# answers        <ans> A product marketer in the SaaS industr...
# llm_input    Below is an instruction that describes a task....
# Name: 383, dtype: object
# prompts        <prompt> Discuss the significance of a succe...
# answers        <ans> A successful product release in the Sa...
# llm_input    Below is an instruction that describes a task....
# Name: 384, dtype: object
# prompts        <prompt> Explain the concept of churn manage...
# answers        <ans> Churn management in the SaaS industry ...
# llm_input    Below is an instruction that describes a task....
# Name: 385, dtype: object
# prompts        <prompt> Discuss the benefits of a seamless ...
# answers        <ans> A seamless billing system migration of...
# llm_input    Below is an instruction that describes a task....
# Name: 386, dtype: object
# prompts        <prompt> Explain the role of industry best p...
# answers        <ans> Industry best practices in the SaaS in...
# llm_input    Below is an instruction that describes a task....
# Name: 387, dtype: object
# prompts        <prompt> Outline the key responsibilities an...
# answers        <ans> A Senior Performance Marketing Manager...
# llm_input    Below is an instruction that describes a task....
# Name: 388, dtype: object
# prompts        <prompt> Identify the major product updates ...
# answers        <ans> In the last year, a SaaS company intro...
# llm_input    Below is an instruction that describes a task....
# Name: 389, dtype: object
# prompts        <prompt> Explain the importance of understan...
# answers        <ans> Understanding subscriber behavior and ...
# llm_input    Below is an instruction that describes a task....
# Name: 390, dtype: object
# prompts        <prompt> Describe the role of RevenueStory i...
# answers        <ans> RevenueStory is a valuable resource fo...
# llm_input    Below is an instruction that describes a task....
# Name: 391, dtype: object
# prompts        <prompt> Discuss the significance of Chargeb...
# answers        <ans> Chargebee's Billing Updates play a sig...
# llm_input    Below is an instruction that describes a task....
# Name: 392, dtype: object
# prompts        <prompt> Explain the concept of 'The Other S...
# answers        <ans> 'The Other Side of RevOps' refers to t...
# llm_input    Below is an instruction that describes a task....
# Name: 393, dtype: object
# prompts        <prompt> Discuss the benefits of subscribing...
# answers        <ans> Subscribing to Chargebee's resources p...
# llm_input    Below is an instruction that describes a task....
# Name: 394, dtype: object
# prompts        <prompt> Explain the concept of 'Moments' in...
# answers        <ans> 'Moments' in Chargebee's marketing str...
# llm_input    Below is an instruction that describes a task....
# Name: 395, dtype: object
# prompts        <prompt> Discuss the importance of demand ge...
# answers        <ans> Demand generation and campaign strateg...
# llm_input    Below is an instruction that describes a task....
# Name: 396, dtype: object
# prompts        <prompt> Explain the role of SEO in the SaaS...
# answers        <ans> SEO plays a vital role in the SaaS ind...
# llm_input    Below is an instruction that describes a task....
# Name: 397, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 398, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 399, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 400, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 401, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 402, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 403, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 404, dtype: object
# prompts        <prompt>Outline the key components of a succ...
# answers        <ans>Successful checkout processes for e-com...
# llm_input    Below is an instruction that describes a task....
# Name: 405, dtype: object
# prompts        <prompt>Explain the importance of declutteri...
# answers        <ans>Decluttering and systemizing a product ...
# llm_input    Below is an instruction that describes a task....
# Name: 406, dtype: object
# prompts        <prompt>Discuss the significance of customer...
# answers        <ans>Customer service plays a vital role in ...
# llm_input    Below is an instruction that describes a task....
# Name: 407, dtype: object
# prompts        <prompt>Describe the potential impact of a "...
# answers        <ans>A "black hole" on an e-commerce checkou...
# llm_input    Below is an instruction that describes a task....
# Name: 408, dtype: object
# prompts        <prompt>Explain the benefits of subscribing ...
# answers        <ans>Subscribing to a source of information ...
# llm_input    Below is an instruction that describes a task....
# Name: 409, dtype: object
# prompts        <prompt>Discuss the role of a reliable payme...
# answers        <ans>A reliable payment gateway is essential...
# llm_input    Below is an instruction that describes a task....
# Name: 410, dtype: object
# prompts        <prompt>Explain the concept of a "moment of ...
# answers        <ans>A "moment of truth" at checkout refers ...
# llm_input    Below is an instruction that describes a task....
# Name: 411, dtype: object
# prompts        <prompt>Outline the benefits of a subscripti...
# answers        <ans>A subscription-based business model can...
# llm_input    Below is an instruction that describes a task....
# Name: 412, dtype: object
# prompts        <prompt>Discuss the importance of industry b...
# answers        <ans>Industry best practices provide busines...
# llm_input    Below is an instruction that describes a task....
# Name: 413, dtype: object
# prompts        <prompt>Explain the concept of a "product ca...
# answers        <ans>A product catalog is a comprehensive li...
# llm_input    Below is an instruction that describes a task....
# Name: 414, dtype: object
# prompts        <prompt> Identify and describe the key takea...
# answers        <ans> Key takeaways from the provided data i...
# llm_input    Below is an instruction that describes a task....
# Name: 415, dtype: object
# prompts        <prompt> Explain the significance of the Cha...
# answers        <ans> The Chargebee and Replly integration m...
# llm_input    Below is an instruction that describes a task....
# Name: 416, dtype: object
# prompts        <prompt> Discuss the concept of churn predic...
# answers        <ans> Churn prediction refers to the process...
# llm_input    Below is an instruction that describes a task....
# Name: 417, dtype: object
# prompts        <prompt> Describe the impact of the Chargebe...
# answers        <ans> The Chargebee and HubSpot integration ...
# llm_input    Below is an instruction that describes a task....
# Name: 418, dtype: object
# prompts        <prompt> Explain the concept of the track, a...
# answers        <ans> The track, act, and prevent approach t...
# llm_input    Below is an instruction that describes a task....
# Name: 419, dtype: object
# prompts        <prompt> Discuss the role of subscription ma...
# answers        <ans> Subscription management plays a crucia...
# llm_input    Below is an instruction that describes a task....
# Name: 420, dtype: object
# prompts        <prompt> Explain the concept of a seamless c...
# answers        <ans> A seamless checkout experience refers ...
# llm_input    Below is an instruction that describes a task....
# Name: 421, dtype: object
# prompts        <prompt> Discuss the impact of the Chargebee...
# answers        <ans> The Chargebee and Replly integration h...
# llm_input    Below is an instruction that describes a task....
# Name: 422, dtype: object
# prompts        <prompt> Explain the concept of post-event s...
# answers        <ans> Post-event subscriber retention in str...
# llm_input    Below is an instruction that describes a task....
# Name: 423, dtype: object
# prompts        <prompt> Discuss the significance of the Cha...
# answers        <ans> The Chargebee and HubSpot integration ...
# llm_input    Below is an instruction that describes a task....
# Name: 424, dtype: object
# prompts        <prompt> Explain the concept of a subscripti...
# ...
# answers        <ans> Simplifying the cancellation process f...
# llm_input    Below is an instruction that describes a task....
# Name: 437, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 488, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 489, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 490, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 491, dtype: object
# prompts        <prompt> Identify and describe the key strat...
# answers        <ans> The key strategies mentioned for maxim...
# llm_input    Below is an instruction that describes a task....
# Name: 492, dtype: object
# prompts        <prompt> List the payment gateways mentioned...
# answers        <ans> The payment gateways mentioned in the ...
# llm_input    Below is an instruction that describes a task....
# Name: 493, dtype: object
# prompts        <prompt> Explain the concept of open banking...
# answers        <ans> Open banking, as described in the text...
# llm_input    Below is an instruction that describes a task....
# Name: 494, dtype: object
# prompts        <prompt> What are the six best practices for...
# answers        <ans> The six best practices for accounts re...
# llm_input    Below is an instruction that describes a task....
# Name: 495, dtype: object
# prompts        <prompt> What are the advantages of using mu...
# answers        <ans> The advantages of using multiple payme...
# llm_input    Below is an instruction that describes a task....
# Name: 496, dtype: object
# prompts        <prompt> What is the purpose of the "2025 Ch...
# answers        <ans> The "2025 Chargebee, Inc" reference in...
# llm_input    Below is an instruction that describes a task....
# Name: 497, dtype: object
# prompts        <prompt> What is the main focus of the "Winn...
# answers        <ans> The main focus of the "Winning the Rec...
# llm_input    Below is an instruction that describes a task....
# Name: 498, dtype: object
# prompts        <prompt> What is the primary goal of the "Ac...
# answers        <ans> The primary goal of the "Ace Customer ...
# llm_input    Below is an instruction that describes a task....
# Name: 499, dtype: object
# prompts        <prompt> What is the purpose of the "2025 Ch...
# answers        <ans> The purpose of the "2025 Chargebee, In...
# llm_input    Below is an instruction that describes a task....
# Name: 500, dtype: object
# prompts        <prompt> What is the main objective of the "...
# answers        <ans> The main objective of the "Choosing th...
# llm_input    Below is an instruction that describes a task....
# Name: 501, dtype: object
# prompts        <prompt> What is the primary focus of the "A...
# answers        <ans> The primary focus of the "A Complete O...
# llm_input    Below is an instruction that describes a task....
# Name: 502, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 504, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 560, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 616, dtype: object
# prompts        <prompt>Identify the key components involved...
# answers        <ans>The key components involved in the fina...
# llm_input    Below is an instruction that describes a task....
# Name: 628, dtype: object
# prompts        <prompt>Explain the significance of the grow...
# answers        <ans>The growth rate is significant as it in...
# llm_input    Below is an instruction that describes a task....
# Name: 629, dtype: object
# prompts        <prompt>Describe the potential impact of a h...
# answers        <ans>A high subscription fee can have a mixe...
# llm_input    Below is an instruction that describes a task....
# Name: 630, dtype: object
# prompts        <prompt>Outline the process of calculating t...
# answers        <ans>The process of calculating the growth r...
# llm_input    Below is an instruction that describes a task....
# Name: 631, dtype: object
# prompts        <prompt>Discuss the potential factors that c...
# answers        <ans>Several factors can influence the activ...
# llm_input    Below is an instruction that describes a task....
# Name: 632, dtype: object
# prompts        <prompt>Explain the relationship between rev...
# answers        <ans>Revenue and active subscribers have a d...
# llm_input    Below is an instruction that describes a task....
# Name: 633, dtype: object
# prompts                                               <prompt>
# answers                                           <ans>  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 634, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 635, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 636, dtype: object
# prompts        <prompt>Identify the key components involved...
# answers        <ans>The key components involved in the fina...
# llm_input    Below is an instruction that describes a task....
# Name: 637, dtype: object
# prompts        <prompt>Explain the significance of the grow...
# answers        <ans>The growth rate is significant as it in...
# llm_input    Below is an instruction that describes a task....
# Name: 638, dtype: object
# prompts        <prompt>Describe the potential impact of a h...
# answers        <ans>A high subscription fee can have a mixe...
# llm_input    Below is an instruction that describes a task....
# Name: 639, dtype: object
# prompts        <prompt>Outline the process of calculating t...
# answers        <ans>The process of calculating the growth r...
# llm_input    Below is an instruction that describes a task....
# Name: 640, dtype: object
# prompts        <prompt>Discuss the potential factors that c...
# answers        <ans>Several factors can influence the activ...
# llm_input    Below is an instruction that describes a task....
# Name: 641, dtype: object
# prompts        <prompt>Explain the relationship between rev...
# answers        <ans>Revenue and active subscribers have a d...
# llm_input    Below is an instruction that describes a task....
# Name: 642, dtype: object
# prompts                                               <prompt>
# answers                                           <ans>  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 643, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 644, dtype: object
# prompts        <prompt>Identify the key components involved...
# answers        <ans>The key components involved in the fina...
# llm_input    Below is an instruction that describes a task....
# Name: 645, dtype: object
# prompts        <prompt>Explain the significance of the grow...
# answers        <ans>The growth rate is significant as it in...
# llm_input    Below is an instruction that describes a task....
# Name: 646, dtype: object
# prompts        <prompt>Describe the potential impact of a h...
# answers        <ans>A high subscription fee can have a mixe...
# llm_input    Below is an instruction that describes a task....
# Name: 647, dtype: object
# prompts        <prompt>Outline the process of calculating t...
# answers        <ans>The process of calculating the growth r...
# llm_input    Below is an instruction that describes a task....
# Name: 648, dtype: object
# prompts        <prompt>Discuss the potential factors that c...
# answers        <ans>Several factors can influence the activ...
# llm_input    Below is an instruction that describes a task....
# Name: 649, dtype: object
# prompts        <prompt>Explain the relationship between rev...
# answers        <ans>Revenue and active subscribers have a d...
# llm_input    Below is an instruction that describes a task....
# Name: 650, dtype: object
# prompts                                               <prompt>
# answers                                           <ans>  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 651, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 652, dtype: object
# prompts                                               <prompt>
# answers                                                  <ans>
# llm_input    Below is an instruction that describes a task....
# Name: 653, dtype: object
# prompts        <prompt> Explain the concept of automated re...
# answers        <ans> Automated recurring payments refer to ...
# llm_input    Below is an instruction that describes a task....
# Name: 654, dtype: object
# prompts        <prompt> Identify the key features of the Ga...
# answers        <ans> The Gateway Evaluator, as mentioned in...
# llm_input    Below is an instruction that describes a task....
# Name: 655, dtype: object
# prompts        <prompt> Discuss the potential advantages of...
# answers        <ans> Using a payment gateway offers several...
# llm_input    Below is an instruction that describes a task....
# Name: 656, dtype: object
# prompts        <prompt> Explain the significance of the lis...
# answers        <ans> The listed countries in the context of...
# llm_input    Below is an instruction that describes a task....
# Name: 657, dtype: object
# prompts        <prompt> Describe the potential impact of au...
# answers        <ans> Automated recurring payments can have ...
# llm_input    Below is an instruction that describes a task....
# Name: 658, dtype: object
# prompts        <prompt> Explain the concept of automated re...
# answers        <ans> Automated recurring payments refer to ...
# llm_input    Below is an instruction that describes a task....
# Name: 659, dtype: object
# prompts        <prompt> Identify the key features of the Ga...
# answers        <ans> The Gateway Evaluator, as mentioned in...
# llm_input    Below is an instruction that describes a task....
# Name: 660, dtype: object
# prompts        <prompt> Discuss the potential advantages of...
# answers        <ans> Using a payment gateway offers several...
# llm_input    Below is an instruction that describes a task....
# Name: 661, dtype: object
# prompts        <prompt> Explain the significance of the lis...
# answers        <ans> The listed countries in the context of...
# llm_input    Below is an instruction that describes a task....
# Name: 662, dtype: object
# prompts        <prompt> Describe the potential impact of au...
# answers        <ans> Automated recurring payments can have ...
# llm_input    Below is an instruction that describes a task....
# Name: 663, dtype: object
# prompts        <prompt>What are the key considerations for ...
# answers        <ans>The key considerations for a SaaS compa...
# llm_input    Below is an instruction that describes a task....
# Name: 664, dtype: object
# prompts        <prompt>What are the benefits of experimenti...
# answers        <ans>The benefits of experimenting with pric...
# llm_input    Below is an instruction that describes a task....
# Name: 665, dtype: object
# prompts        <prompt>What are the two pricing models ment...
# answers        <ans>The two pricing models mentioned in the...
# llm_input    Below is an instruction that describes a task....
# Name: 666, dtype: object
# prompts        <prompt>What are the potential drawbacks of ...
# answers        <ans>The potential drawbacks of a linear sca...
# llm_input    Below is an instruction that describes a task....
# Name: 667, dtype: object
# prompts        <prompt>How can a SaaS company determine the...
# answers        <ans>A SaaS company can determine the right ...
# llm_input    Below is an instruction that describes a task....
# Name: 668, dtype: object
# prompts        <prompt> Explain the concept of automated re...
# answers        <ans> Automated recurring payments refer to ...
# llm_input    Below is an instruction that describes a task....
# Name: 669, dtype: object
# prompts        <prompt> Identify the key features of the Ga...
# answers        <ans> The Gateway Evaluator, as mentioned in...
# llm_input    Below is an instruction that describes a task....
# Name: 670, dtype: object
# prompts        <prompt> Discuss the potential advantages of...
# answers        <ans> Using a payment gateway offers several...
# llm_input    Below is an instruction that describes a task....
# Name: 671, dtype: object
# prompts        <prompt> Explain the significance of the lis...
# answers        <ans> The listed countries in the context of...
# llm_input    Below is an instruction that describes a task....
# Name: 672, dtype: object
# prompts        <prompt> Describe the potential impact of au...
# answers        <ans> Automated recurring payments can have ...
# llm_input    Below is an instruction that describes a task....
# Name: 673, dtype: object
# prompts        <prompt> Identify the key areas of expertise...
# answers        <ans> The key areas of expertise for the ind...
# llm_input    Below is an instruction that describes a task....
# Name: 674, dtype: object
# prompts        <prompt> Describe the professional backgroun...
# answers        <ans> The individual mentioned in the text h...
# llm_input    Below is an instruction that describes a task....
# Name: 675, dtype: object
# prompts        <prompt> What are some of the best practices...
# answers        <ans> Some of the best practices mentioned i...
# llm_input    Below is an instruction that describes a task....
# Name: 676, dtype: object
# prompts        <prompt> What is the purpose of the "Release...
# answers        <ans> The purpose of the "Release Roundup" m...
# llm_input    Below is an instruction that describes a task....
# Name: 677, dtype: object
# prompts        <prompt> What is the significance of the "Pr...
# answers        <ans> The "Product Updates" mentioned in the...
# llm_input    Below is an instruction that describes a task....
# Name: 678, dtype: object
# prompts        <prompt> What is the role of the individual ...
# answers        <ans> In the "Migrating 12 Million Records f...
# llm_input    Below is an instruction that describes a task....
# Name: 679, dtype: object
# prompts        <prompt>Describe the financial benefits that...
# answers        <ans>By integrating Chargebee and Pipe into ...
# llm_input    Below is an instruction that describes a task....
# Name: 680, dtype: object
# prompts        <prompt>Explain how the integration of Charg...
# answers        <ans>The integration of Chargebee and Pipe p...
# llm_input    Below is an instruction that describes a task....
# Name: 681, dtype: object
# prompts        <prompt>Discuss the impact of the subscripti...
# answers        <ans>The subscription-based business model h...
# llm_input    Below is an instruction that describes a task....
# Name: 682, dtype: object
# prompts        <prompt>Generate a list of key features that...
# answers        <ans>1. Trigger-based Emails: Emails sent ou...
# llm_input    Below is an instruction that describes a task....
# Name: 683, dtype: object

# %%
len(train_loader)
# Out:
# 0

# %%
val_dataset = InstructionDataset(val_data, tokenizer)
val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    collate_fn = customized_collate_fn,
    shuffle=True,
    drop_last= True,
    num_workers = num_workers
)
# Out:
# prompts        <prompt>Formulate a prompt that requests a d...
# answers        <ans>Discuss the potential long-term sustain...
# llm_input    Below is an instruction that describes a task....
# Name: 720, dtype: object
# prompts        <prompt>Generate a prompt that asks for an e...
# answers        <ans>Explain the benefits of ecommerce subsc...
# llm_input    Below is an instruction that describes a task....
# Name: 721, dtype: object
# prompts        <prompt>Create a prompt that requests a comp...
# answers        <ans>Compare the unique features and target ...
# llm_input    Below is an instruction that describes a task....
# Name: 722, dtype: object
# prompts        <prompt>Formulate a prompt that asks for an ...
# answers        <ans>Analyze the role of technology in the g...
# llm_input    Below is an instruction that describes a task....
# Name: 723, dtype: object
# prompts        <prompt>Describe the relationship between tw...
# answers        <ans>The relationship between Intruder and C...
# llm_input    Below is an instruction that describes a task....
# Name: 724, dtype: object
# prompts        <prompt>Explain the purpose of a specific pl...
# answers        <ans>The purpose of ChartMogul's Subscriptio...
# llm_input    Below is an instruction that describes a task....
# Name: 725, dtype: object
# prompts        <prompt>Identify the type of service or plat...
# answers        <ans>The service mentioned in the text is Ch...
# llm_input    Below is an instruction that describes a task....
# Name: 726, dtype: object
# prompts        <prompt> Explain the key steps involved in c...
# answers        <ans> Creating a successful SaaS audience in...
# llm_input    Below is an instruction that describes a task....
# Name: 727, dtype: object
# prompts        <prompt> Describe the significance of the B2...
# answers        <ans> The B2B Rocks conference holds signifi...
# llm_input    Below is an instruction that describes a task....
# Name: 728, dtype: object
# prompts        <prompt> Discuss the role of ChartMogul's Su...
# answers        <ans> ChartMogul's Subscription Analytics Pl...
# llm_input    Below is an instruction that describes a task....
# Name: 729, dtype: object
# prompts        <prompt> Explain the concept of a starter ch...
# answers        <ans> Starter Churn Insights is a concept th...
# llm_input    Below is an instruction that describes a task....
# Name: 730, dtype: object
# prompts        <prompt> Discuss the importance of localizat...
# answers        <ans> Localization plays a crucial role in t...
# llm_input    Below is an instruction that describes a task....
# Name: 731, dtype: object
# prompts        <prompt> Describe the role of subscriptions ...
# answers        <ans> Subscriptions play a significant role ...
# llm_input    Below is an instruction that describes a task....
# Name: 732, dtype: object
# prompts        <prompt>Describe the challenges faced by the...
# answers        <ans>The finance team in the SaaS business f...
# llm_input    Below is an instruction that describes a task....
# Name: 733, dtype: object
# prompts        <prompt>Explain how Chargebee's automation a...
# answers        <ans>Chargebee's automation and integrative ...
# llm_input    Below is an instruction that describes a task....
# Name: 734, dtype: object
# prompts        <prompt> Explain the professional background...
# answers        <ans> The individual mentioned in the text, ...
# llm_input    Below is an instruction that describes a task....
# Name: 735, dtype: object
# prompts        <prompt> Identify the strategies mentioned i...
# answers        <ans> The text mentions six proven strategie...
# llm_input    Below is an instruction that describes a task....
# Name: 736, dtype: object
# prompts        <prompt> Describe the benefits of subscribin...
# answers        <ans> Subscribing to the source mentioned in...
# llm_input    Below is an instruction that describes a task....
# Name: 737, dtype: object
# prompts        <prompt> Explain the concept of SaaS pricing...
# answers        <ans> SaaS pricing models refer to the vario...
# llm_input    Below is an instruction that describes a task....
# Name: 738, dtype: object

# %%
test_dataset = InstructionDataset(test_data, tokenizer)
test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    collate_fn = customized_collate_fn,
    shuffle=True,
    drop_last= True,
    num_workers = num_workers
)
# Out:
# prompts        <prompt> Identify the key strategies mention...
# answers        <ans> The key strategies mentioned in the te...
# llm_input    Below is an instruction that describes a task....
# Name: 684, dtype: object
# prompts        <prompt> Explain the importance of product u...
# answers        <ans> Product updates and subscriptions play...
# llm_input    Below is an instruction that describes a task....
# Name: 685, dtype: object
# prompts        <prompt> Discuss the significance of multi-c...
# answers        <ans> Multi-currency and multi-lingual suppo...
# llm_input    Below is an instruction that describes a task....
# Name: 686, dtype: object
# prompts        <prompt> What are the benefits of implementi...
# answers        <ans> Implementing ASC 606, as mentioned in ...
# llm_input    Below is an instruction that describes a task....
# Name: 687, dtype: object
# prompts        <prompt> How can businesses leverage free tr...
# answers        <ans> Businesses can leverage free trials as...
# llm_input    Below is an instruction that describes a task....
# Name: 688, dtype: object
# prompts        <prompt>Outline the key considerations and s...
# answers        <ans>1. Incorporating in the USA as a Delawa...
# llm_input    Below is an instruction that describes a task....
# Name: 689, dtype: object
# prompts        <prompt>Identify the key components involved...
# answers        <ans>The key components involved in the fina...
# llm_input    Below is an instruction that describes a task....
# Name: 690, dtype: object
# prompts        <prompt>Explain the significance of the grow...
# answers        <ans>The growth rate is significant as it in...
# llm_input    Below is an instruction that describes a task....
# Name: 691, dtype: object
# prompts        <prompt>Describe the potential impact of a h...
# answers        <ans>A high subscription fee can have a mixe...
# llm_input    Below is an instruction that describes a task....
# Name: 692, dtype: object
# prompts        <prompt>Outline the process of calculating t...
# answers        <ans>The process of calculating the growth r...
# llm_input    Below is an instruction that describes a task....
# Name: 693, dtype: object
# prompts        <prompt>Discuss the potential factors that c...
# answers        <ans>Several factors can influence the activ...
# llm_input    Below is an instruction that describes a task....
# Name: 694, dtype: object
# prompts        <prompt>Explain the relationship between rev...
# answers        <ans>Revenue and active subscribers have a d...
# llm_input    Below is an instruction that describes a task....
# Name: 695, dtype: object
# prompts        <prompt> Identify the key factors that contr...
# answers        <ans> The key factors contributing to the su...
# llm_input    Below is an instruction that describes a task....
# Name: 696, dtype: object
# prompts        <prompt> Discuss the importance of diversity...
# answers        <ans> Diversity and self-reinvention play a ...
# llm_input    Below is an instruction that describes a task....
# Name: 697, dtype: object
# prompts        <prompt> Explain the significance of buildin...
# answers        <ans> Building a local team is a crucial asp...
# llm_input    Below is an instruction that describes a task....
# Name: 698, dtype: object
# prompts        <prompt> Describe the growth trajectory of F...
# answers        <ans> Freshdesk has experienced significant ...
# llm_input    Below is an instruction that describes a task....
# Name: 699, dtype: object
# prompts        <prompt> Discuss the challenges involved in ...
# answers        <ans> Expanding a SaaS product to a new mark...
# llm_input    Below is an instruction that describes a task....
# Name: 700, dtype: object
# prompts        <prompt> Explain the importance of declutter...
# answers        <ans> Decluttering and systemizing a product...
# llm_input    Below is an instruction that describes a task....
# Name: 701, dtype: object
# prompts        <prompt> What are some benefits of subscribi...
# answers        <ans> Subscribing to industry best practices...
# llm_input    Below is an instruction that describes a task....
# Name: 702, dtype: object
# prompts        <prompt> How can data-driven pricing decisio...
# answers        <ans> Data-driven pricing decisions can have...
# llm_input    Below is an instruction that describes a task....
# Name: 703, dtype: object
# prompts        <prompt> What are some key factors to consid...
# answers        <ans> When creating a subscription model, bu...
# llm_input    Below is an instruction that describes a task....
# Name: 704, dtype: object
# prompts        <prompt> How can a subscription service help...
# answers        <ans> A subscription service can help a busi...
# llm_input    Below is an instruction that describes a task....
# Name: 705, dtype: object
# prompts        <prompt>Generate a list of the key component...
# answers        <ans>The key components of the FTC's Negativ...
# llm_input    Below is an instruction that describes a task....
# Name: 706, dtype: object
# prompts        <prompt>Explain how Chargebee Retention can ...
# answers        <ans>Chargebee Retention can assist business...
# llm_input    Below is an instruction that describes a task....
# Name: 707, dtype: object
# prompts        <prompt>Describe the purpose of the cancel p...
# answers        <ans>The purpose of the cancel page in the c...
# llm_input    Below is an instruction that describes a task....
# Name: 708, dtype: object
# prompts        <prompt>What is the significance of loss ave...
# answers        <ans>The significance of loss aversion offer...
# llm_input    Below is an instruction that describes a task....
# Name: 709, dtype: object
# prompts        <prompt>How can businesses balance complianc...
# answers        <ans>Businesses can balance compliance with ...
# llm_input    Below is an instruction that describes a task....
# Name: 710, dtype: object
# prompts        <prompt>What are the key characteristics of ...
# answers        <ans>The key characteristics of an antifragi...
# llm_input    Below is an instruction that describes a task....
# Name: 711, dtype: object
# prompts        <prompt>How does an antifragile revenue oper...
# answers        <ans>An antifragile revenue operations workf...
# llm_input    Below is an instruction that describes a task....
# Name: 712, dtype: object
# prompts        <prompt>Generate a list of key metrics that ...
# answers        <ans>1. Monthly Recurring Revenue (MRR): MRR...
# llm_input    Below is an instruction that describes a task....
# Name: 713, dtype: object
# prompts        <prompt>Describe the potential impacts of th...
# answers        <ans>The new revenue recognition standard, A...
# llm_input    Below is an instruction that describes a task....
# Name: 714, dtype: object
# prompts        <prompt>Generate a prompt that asks for an a...
# answers        <ans>Analyze the growth trends in ecommerce ...
# llm_input    Below is an instruction that describes a task....
# Name: 715, dtype: object
# prompts        <prompt>Create a prompt that requests a comp...
# answers        <ans>Compare the popularity and growth rates...
# llm_input    Below is an instruction that describes a task....
# Name: 716, dtype: object
# prompts        <prompt>Formulate a prompt that asks for an ...
# answers        <ans>Evaluate the benefits and challenges th...
# llm_input    Below is an instruction that describes a task....
# Name: 717, dtype: object
# prompts        <prompt>Generate a prompt that requests an e...
# answers        <ans>Explain the significance of personaliza...
# llm_input    Below is an instruction that describes a task....
# Name: 718, dtype: object
# prompts        <prompt>Create a prompt that asks for an ana...
# answers        <ans>Analyze the impact of the pandemic on t...
# llm_input    Below is an instruction that describes a task....
# Name: 719, dtype: object

# %%
import torch
from evaluate import evaluate_model, generate_and_print_sample, calc_loss_batch
from model import CoreModel
from preprocess_transformer_data import create_dataloader_v1

# %%
from psutil import virtual_memory
import multiprocessing

import time
start_time = time.time()
torch.manual_seed(123)
# from config import CORE_TRANSFORMER_CONFIG
from torch.utils.data import random_split
from torch import nn
from tqdm import tqdm


cpu_count = multiprocessing.cpu_count()

mem = virtual_memory()
mem = round(mem.total / 1000000000, 1)

# %%
CONFIG={
    "vocab_size": 50256, # Vocabulary size
    "context_length": 1024, # Context length
    "emb_dim": 768, # Embedding dimension
    "n_heads":12, # Number of attention heads
    "n_layers": 12, # Number of layers
    "drop_rate": 0.0, # Dropout rate
    "qkv_bias": False, # Query-Key-Value bias
    "lr": 6e-5 # Learning rate
}

# %%
model =  CoreModel(CONFIG)

# %%
model_state_dict = torch.load(f"C://Users/tsuma.thomas/Documents/core_foundation_2.pth")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model_state_dict = torch.load(f"C://Users/tsuma.thomas/Documents/core_foundation_2.pth")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\serialization.py:1432, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1430 orig_position = opened_file.tell()
#    1431 overall_storage = None
# -> 1432 with _open_zipfile_reader(opened_file) as opened_zipfile:
#    1433     if _is_torchscript_zip(opened_zipfile):
#    1434         warnings.warn(
#    1435             "'torch.load' received a zip file that looks like a TorchScript archive"
#    1436             " dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to"
#    1437             " silence this warning)",
#    1438             UserWarning,
#    1439         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\serialization.py:763, in _open_zipfile_reader.__init__(self, name_or_buffer)
#     762 def __init__(self, name_or_buffer) -> None:
# --> 763     super().__init__(torch._C.PyTorchFileReader(name_or_buffer))
#
# RuntimeError: PytorchStreamReader failed reading zip archive: failed finding central directory

# %%
model.load_state_dict(model_state_dict)
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# CoreModel(
#   (tok_emb): Embedding(50256, 768)
#   (pos_emb): Embedding(1024, 768)
#   (drop_emb): Dropout(p=0.0, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (1): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (2): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (3): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (4): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (5): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (6): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (7): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (8): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (9): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (10): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (11): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (final_norm): LayerNormalization()
#   (out_head): Linear(in_features=768, out_features=50256, bias=False)
# )

# %%
torch.manual_seed(123)
input_text = format_input(val_data.iloc[10])
print(input_text)
# Out:
# prompts        <prompt> Explain the concept of a starter ch...
# answers        <ans> Starter Churn Insights is a concept th...
# llm_input    Below is an instruction that describes a task....
# Name: 730, dtype: object
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
#  ### Instruction:
#  Explain the concept of a starter churn insights and its relevance to startups.

# %%
def generate(model, idx, max_new_tokens, context_size, temperature=0.0, top_k=None, eos_id=None):
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]

        if top_k is not None:
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(
                logits < min_val,
                torch.tensor(float('-inf')).to(logits.device),
                logits
            )
        if temperature > 0.0:
            logits = logits / temperature
            probs = torch.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)
        if idx_next == eos_id:
            break
        idx = torch.cat((idx, idx_next), dim=1)
    return idx

# %%
def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0)
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0)
    return tokenizer.decode(flat.tolist())

# %%
token_ids = generate(
    model=model,
    idx=text_to_token_ids(input_text, tokenizer),
    max_new_tokens=35,
    context_size=CONFIG["context_length"],
    eos_id=50256,
)

# %%
token_ids
# Out:
# tensor([[21106,   318,   281, 12064,   326,  8477,   257,  4876,    13, 19430,
#            257,  2882,   326, 20431, 32543,   262,  2581,    13,   628, 44386,
#          46486,    25,   198, 48605,   262,  3721,   286,   257, 14217, 28488,
#          17218,   290,   663, 23082,   284, 21685,    13,   770,   318,   257,
#           2383, 23554,   329,   262, 15549,    11,   810,   262,  1230,   468,
#            587,   319,   262,  1499,    13,   383,   649, 49117,   284,   262,
#           1499,   264, 12396,  3349,   290, 13347,  2478,   290, 13347,  2478,
#             11,  1390]])

# %%
generated_text = token_ids_to_text(token_ids, tokenizer)

# %%
generated_text
# Out:
# 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n ### Instruction:\n Explain the concept of a starter churn insights and its relevance to startups. This is a significant milestone for the continent, where the government has been on the country. The new entrants to the country s GDP growth and sustainable development and sustainable development, including'

# %%
def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(
            input_batch, target_batch, model, device
            )
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
model.train()
# Out:
# CoreModel(
#   (tok_emb): Embedding(50256, 768)
#   (pos_emb): Embedding(1024, 768)
#   (drop_emb): Dropout(p=0.0, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (1): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (2): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (3): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (4): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (5): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (6): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (7): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (8): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (9): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (10): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#     (11): TransformerBlock(
#       (attn): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=False)
#         (W_key): Linear(in_features=768, out_features=768, bias=False)
#         (W_value): Linear(in_features=768, out_features=768, bias=False)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNormalization()
#       (norm2): LayerNormalization()
#       (drop_shortcut): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (final_norm): LayerNormalization()
#   (out_head): Linear(in_features=768, out_features=50256, bias=False)
# )

# %%
with torch.no_grad():
    train_loss = calc_loss_loader(
        train_loader, model, device, num_batches=5
    )
    val_loss = calc_loss_loader(
        val_loader, model, device, num_batches=5
    )

# %%
print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: nan
# Validation loss: nan

# %%
def train_model_simple(config,  model, train_loader, val_loader, start_context=format_input(val_data.iloc[0]), tokenizer=tokenizer):
    num_epochs=2
    eval_freq=5
    eval_iter=2
    
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # wandb.watch(model, log="all", log_freq=10)

   
    optimizer = torch.optim.AdamW(model.parameters(), lr=config['lr'], weight_decay=0.1)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50, eta_min=6e-6)
    print(scheduler.get_last_lr()[0])
    curr_loss = None
    for epoch in range(num_epochs):
        if epoch > 100:
            config['dropout'] = 0.1
        print(f"Epoch {epoch+1} training start...")
        
        
        for input_batch, target_batch in tqdm(train_loader, desc=f"Epoch {epoch+1}"):
            optimizer.zero_grad()
            loss = calc_loss_batch(
                input_batch, target_batch, model, device
            )
            loss.backward()
            optimizer.step()
            scheduler.step()
            tokens_seen += input_batch.numel()
            global_step += 1
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                f"Train loss {train_loss:.3f}, "
                f"Val loss {val_loss:.3f}"
                )
           
            if curr_loss is None or loss.item() <= curr_loss:
                curr_loss = loss.item()
                # torch.save(model.state_dict(), f"/home/core/transformers/models/core_foundation_2.pth")


            # ray.train.report({"loss":val_loss})
            model.eval()
            start_context = "What is MRR?"
            gen_result = generate_and_print_sample(
                model, tokenizer, device, start_context
            )
            # logger.info(f"Generated text: {gen_result}")    
            model.train()
    return train_losses, val_losses, track_tokens_seen
# Out:
# prompts        <prompt>Formulate a prompt that requests a d...
# answers        <ans>Discuss the potential long-term sustain...
# llm_input    Below is an instruction that describes a task....
# Name: 720, dtype: object

# %%
import time
start_time = time.time()
torch.manual_seed(123)
train_losses, val_losses, tokens_seen = train_model_simple(
    CONFIG,model, train_loader, val_loader, start_context=format_input(val_data.iloc[0]), tokenizer=tokenizer
)
end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# prompts        <prompt>Formulate a prompt that requests a d...
# answers        <ans>Discuss the potential long-term sustain...
# llm_input    Below is an instruction that describes a task....
# Name: 720, dtype: object
# 6e-05
# Epoch 1 training start...
# Epoch 1: 0it [00:00, ?it/s]
