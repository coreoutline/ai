# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import requests
import json
import tqdm
import numpy as np
from transformers import AutoTokenizer

# %%
import ollama

client = ollama.Client()

# %%
response = client.generate(model="llama3.2", prompt=f"""What metrics are good to track for my business""")

# %%
response
# Out:
# GenerateResponse(model='llama3.2', created_at='2025-04-30T16:48:18.3083765Z', done=True, done_reason='stop', total_duration=19050586700, load_duration=110053200, prompt_eval_count=34, prompt_eval_duration=102000000, eval_count=690, eval_duration=17580000000, response='The key performance indicators (KPIs) you should track will depend on your business goals and objectives. Here are some common metrics that can be useful to track:\n\n**Financial Metrics:**\n\n1. Revenue growth: Track the increase or decrease in revenue over time.\n2. Profit margin: Calculate the difference between revenue and expenses to ensure a healthy profit margin.\n3. Gross margin: Measure the profitability of your products or services by tracking the difference between revenue and cost of goods sold (COGS).\n4. Operating income: Track the company\'s earnings before interest, taxes, depreciation, and amortization (EBITDA) to measure its overall financial performance.\n5. Cash flow: Monitor the company\'s ability to generate cash from operations, investments, and financing activities.\n\n**Customer Metrics:**\n\n1. Customer acquisition cost (CAC): Calculate the cost of acquiring a new customer, including marketing, sales, and other expenses.\n2. Customer retention rate: Track the percentage of customers who remain loyal over time.\n3. Customer satisfaction (CSAT) score: Measure customer satisfaction through surveys or feedback forms.\n4. Net promoter score (NPS): Gauge customer loyalty by asking one simple question: "On a scale of 0-10, how likely are you to recommend our company to a friend or colleague?"\n5. Sales pipeline growth: Track the number of new leads, opportunities, and closed deals to measure sales performance.\n\n**Operational Metrics:**\n\n1. Production capacity utilization: Measure the percentage of production capacity being used.\n2. Inventory turnover rate: Track the number of times inventory is sold and replaced within a given period.\n3. Supply chain efficiency: Monitor the speed, reliability, and cost-effectiveness of your supply chain.\n4. Employee productivity: Measure the output and quality of work produced by employees.\n5. Customer service response time: Track the time it takes to respond to customer inquiries or complaints.\n\n**Marketing Metrics:**\n\n1. Website traffic: Monitor the number of visitors to your website.\n2. Social media engagement: Track likes, shares, comments, and followers on social media platforms.\n3. Email open rates and click-through rates (CTR): Measure the effectiveness of email marketing campaigns.\n4. Lead generation: Track the number of leads generated through various marketing channels.\n5. Return on investment (ROI) for marketing campaigns: Calculate the revenue generated by each marketing campaign to determine its effectiveness.\n\n**Digital Metrics:**\n\n1. Website analytics: Monitor user behavior, such as page views, bounce rates, and time on site.\n2. Search engine optimization (SEO): Track rankings and traffic from search engines like Google.\n3. Mobile app downloads and usage: Measure the number of users and engagement with your mobile app.\n4. Social media metrics: Track follower growth, engagement, and content performance.\n5. Online review management: Monitor and respond to customer reviews on platforms like Yelp or Google.\n\n**Other Metrics:**\n\n1. Employee satisfaction: Conduct regular surveys to gauge employee morale and job satisfaction.\n2. Industry benchmarking: Compare your business\'s performance with industry averages or competitors.\n3. Market share: Track the percentage of market share held by your business.\n4. Innovation pipeline: Monitor the development and implementation of new products, services, or technologies.\n\nRemember to choose metrics that align with your business goals and objectives. It\'s also essential to regularly review and adjust your KPIs as your business evolves.', context=[128006, 9125, 128007, 271, 38766, 1303, 33025, 2696, 25, 6790, 220, 2366, 18, 271, 128 ...

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:960, in Response.json(self, **kwargs)
#     959 try:
# --> 960     return complexjson.loads(self.content.decode(encoding), **kwargs)
#     961 except UnicodeDecodeError:
#     962     # Wrong UTF codec detected; usually because it's not UTF-8
#     963     # but some other 8-bit codec.  This is an RFC violation,
#     964     # and the server didn't bother to tell us what codec *was*
#     965     # used.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 2 column 1 (char 95)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = response.json()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:968, in Response.json(self, **kwargs)
#     966             pass
#     967         except JSONDecodeError as e:
# --> 968             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     970 try:
#     971     return complexjson.loads(self.text, **kwargs)
#
# JSONDecodeError: Extra data: line 2 column 1 (char 95)

# %%
logits = torch.tensor(data["logits"])
