# %%
import pandas as pd

# %%
with open("C://Users/tsuma.thomas/Documents/Text-Generation-with-Decoder-Architecture/adhoc/content2.txt", "r") as f:
    text = f.read()

# %%
texts = text.split("<|end_of_text|>")

# %%
len(texts[0].split(" "))
# Out:
# 170
