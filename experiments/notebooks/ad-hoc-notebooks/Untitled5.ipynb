# %%
from transformers import AutoModel, AutoTokenizer

# %%
# !pip install --upgrade transformers
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB 262.6 kB/s eta 0:00:43
#    ---------------------------------------- 0.0/11.3 MB 196.9 kB/s eta 0:00:58
#    ---------------------------------------- 0.1/11.3 MB 272.3 kB/s eta 0:00:42
#    ---------------------------------------- 0.1/11.3 MB 286.7 kB/s eta 0:00:40
#    ---------------------------------------- 0.1/11.3 MB 328.0 kB/s eta 0:00:35
#    ---------------------------------------- 0.1/11.3 MB 359.9 kB/s eta 0:00:31
#    ---------------------------------------- 0.1/11.3 MB 357.2 kB/s eta 0:00:32
#     --------------------------------------- 0.2/11.3 MB 366.6 kB/s eta 0:00:31
#     --------------------------------------- 0.2/11.3 MB 384.3 kB/s eta 0:00:29
# ...

# %%
model_path = "core-outline/nyx"
tokenizer = AutoTokenizer.from_pretrained("core-outline/nyx")
model = AutoModel.from_pretrained(model_path, trust_remote_code=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\auto\configuration_auto.py:1092, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1091 try:
# -> 1092     config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1093 except KeyError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\auto\configuration_auto.py:794, in _LazyConfigMapping.__getitem__(self, key)
#     793 if key not in self._mapping:
# --> 794     raise KeyError(key)
#     795 value = self._mapping[key]
#
# KeyError: 'core_outline_nyx'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
def generate_text(prompt, max_length=100, temperature=0.7):
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(
        inputs.input_ids,
        max_new_tokens=max_length,
        context_size=10240,
        temperature=temperature,
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)


generate_text("What is MRR?")

# %%
from transformers import AutoTokenizer, AutoModel

# %%
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen1.5-0.5B")
model = AutoModel.from_pretrained("Qwen/Qwen1.5-0.5B")
# Out:
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.24G [00:00<?, ?B/s]

# %%
start_context = "def calculateArea():"
inputs = tokenizer(start_context, return_tensors="pt")

# %%
inputs
# Out:
# {'input_ids': tensor([[  750, 11047,  8726,  4555]]), 'attention_mask': tensor([[1, 1, 1, 1]])}
